# %% [markdown]
# ## Извлечение отношений

# %% [markdown]
# Подготовка данных

# %%
import json
import os
from collections import Counter
from itertools import combinations
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans
from scipy.sparse import hstack
from collections import defaultdict
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import gensim

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
data = json.load(open('train.json'))

# %%
c = Counter([len(data[k]) for k in data])

# %%
ent1 = []
ent2 = []

left = []
right = []
middle = []

sents = []

target = []

for key in data:

    for instance in data[key]:
        
        tokens = instance['tokens']
        sents.append(tokens)
        
        ent1.append(' '.join([tokens[i] for i in instance['h'][2][0]]))
        ent2.append(' '.join([tokens[i] for i in instance['t'][2][0]]))

        if instance['h'][2][0][0] < instance['t'][2][0][0]:
            first, second = 'h', 't'
        else:
            second, first = 'h', 't'

        first_start = instance[first][2][0][0]
        first_end = instance[first][2][0][-1]
        second_start = instance[second][2][0][0]
        second_end = instance[second][2][0][-1]

        left_context = tokens[max(0, first_start-3):first_start]
        left.append((['<START>']*(3-len(left_context))) + left_context)
        
        right_context = tokens[second_end+1:second_end+4]
        right.append(right_context + (['<END>']*(3-len(right_context))))

        middle_context = tokens[first_end+1:second_start]
        middle.append(middle_context)

        target.append(key)

# %%
lefts_s = [' '.join(l) for l in left]
rights_s = [' '.join(l) for l in right]
middles_s = [' '.join(l) for l in middle]

# %% [markdown]
# ### Обучение w2v модели (данные: корпус nltk.reuters и датасет с webhose.io)

# %%
from nltk.corpus import reuters

# %%
docs=[]
for category in reuters.categories():
    for fileid in reuters.fileids(category):
        docs.append([x for x in reuters.raw(fileid).split()])

# %%
len(docs)
# Out:
# 13328

# %%
files = os.listdir('news')

# %%
dirname = os.path.join(os.getcwd(), 'news')

# %%
documents = []
for fname in files:
    with open(os.path.join(dirname, fname), 'r', encoding='utf-8') as f:
        d = json.load(f)
        if 'text' in d.keys():
            documents.append([x for x in d['text'].split()])

# %%
len(documents)
# Out:
# 164

# %%
docs.extend(documents)

# %%
len(docs)
# Out:
# 13492

# %%
model = gensim.models.Word2Vec(docs)

# %%
DIM = 100

# %% [markdown]
# Подготовка эмбеддингов

# %%
def get_embedding(text, model, dim = DIM):
    text = text.split()
    words = Counter(text)
    total = len(text)
    vectors = np.zeros((len(words), dim))    
    for i,word in enumerate(words):
        try:
            v = model[word]
            vectors[i] = v*(words[word]/total)
        except (KeyError, ValueError):
            continue   
    if vectors.any():
        vector = np.average(vectors, axis=0)
    else:
        vector = np.zeros((dim))    
    return vector

# %% [markdown]
# Сначала попробуем создать отдельно эмбеддинги для каждого окна, затем сконкатенировать получившиеся матрицы:

# %%
X_l = np.zeros((len(lefts_s), DIM))
X_m = np.zeros((len(middles_s), DIM))
X_r = np.zeros((len(rights_s), DIM))

# %%
for i, text in enumerate(lefts_s):
    X_l[i] = get_embedding(text, model)

# %%
for i, text in enumerate(middles_s):
    X_m[i] = get_embedding(text, model)

# %%
for i, text in enumerate(rights_s):
    X_r[i] = get_embedding(text, model)

# %%
from scipy.sparse import coo_matrix

# %%
X = csr_matrix(hstack([coo_matrix(X_l), coo_matrix(X_m), coo_matrix(X_r)]))

# %%
X.shape
# Out:
# (44800, 300)

# %% [markdown]
# Также попробуем создать эмбеддинги целых предложений:

# %%
X_s = np.zeros((len(sents), DIM))

for i, text in enumerate(sents):
    X_s[i] = get_embedding(text, model)

# %%
X_ = csr_matrix(X_s)

# %%
y = np.array(target)

# %%
len(y)
# Out:
# 44800

# %% [markdown]
# ### Эмбеддинги отдельных окон, логистическая регрессия
#
# Обучение SGD на этих эмбеддингах давало чуть лучший результат, чем на эмбеддингах предложений; результат применения логистической регрессии существенно лучше

# %%
N = 4
skf = StratifiedKFold(n_splits=N, shuffle=True)
metrics_macro = np.zeros((3))
metrics_micro = np.zeros((3))
conf = np.zeros((len(set(y)), len(set(y))))

for train_index, test_index in skf.split(X, y):
    #clf = SGDClassifier(max_iter=1000, tol=1e-3)
    clf = LogisticRegression()
    clf.fit(X[train_index], y[train_index])
    preds = clf.predict(X[test_index])
    
    metrics_macro += precision_recall_fscore_support(y[test_index], preds, average='macro')[:3]
    metrics_micro += precision_recall_fscore_support(y[test_index], preds, average='micro')[:3]
    
    conf += confusion_matrix(y[test_index], preds)

# %%
print(metrics_micro/N)
print(metrics_macro/N)
# Out:
# [0.21977679 0.21977679 0.21977679]
# [0.21337853 0.21977679 0.20178167]

# %% [markdown]
# ### Эмбеддинги предложений, SGD

# %%
from sklearn.linear_model import SGDClassifier

N = 4
skf = StratifiedKFold(n_splits=N, shuffle=True)
metrics_macro = np.zeros((3))
metrics_micro = np.zeros((3))
conf = np.zeros((len(set(y)), len(set(y))))

for train_index, test_index in skf.split(X, y):
    clf = SGDClassifier()
    clf.fit(X_[train_index], y[train_index])
    preds = clf.predict(X_[test_index])
    
    metrics_macro += precision_recall_fscore_support(y[test_index], preds, average='macro')[:3]
    metrics_micro += precision_recall_fscore_support(y[test_index], preds, average='micro')[:3]
    
    conf += confusion_matrix(y[test_index], preds)

# %%
print(metrics_micro/N)
print(metrics_macro/N)
# Out:
# [0.13241071 0.13241071 0.13241071]
# [0.24676732 0.13241071 0.11315794]

# %% [markdown]
# ### Confusion matrix (используется классификатор с логистической регрессией)

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(data=np.round(conf/3).astype(int), 
            annot=True, 
            fmt="d", xticklabels=clf.classes_, yticklabels=clf.classes_, ax=ax)
plt.title("Confusion matrix")
plt.show()

# %% [markdown]
# Видно, что часто путаемые классы - это, например, Р102 и Р106: "член политической партии" и "занятие (occupation)". Действительно, политическая деятельность члена партии и является его занятием, и предложения с данными сущностями, скорее всего, будут похожи. Посмотрим на примеры предложений с сущностями данных классов:

# %%
data['P102']
# Out:
# [{'tokens': ['Rempel',
#    'became',
#    'involved',
#    'in',
#    'politics',
#    'with',
#    'the',
#    'riding',
#    'association',
#    'of',
#    'Diane',
#    'Ablonczy',
#    ',',
#    'and',
#    'she',
#    'later',
#    'served',
#    'as',
#    'president',
#    'of',
#    'the',
#    'Conservative',
#    'Party',
#    'riding',
#    'executive',
#    'for',
#    'her',
#    'riding',
#    'of',
#    'Calgary',
#    '—',
#    'Nose',
#    'Hill',
#    '.'],
#   'h': ['diane ablonczy', 'Q3026184', [[10, 11]]],
#   't': ['conservative party', 'Q488523', [[21, 22]]]},
#  {'tokens': ['Hubert',
#    'Ney',
#    '(',
#    '12',
#    'October',
#    '1892',
#    '–',
#    '3',
#    'February',
#    '1984',
#    ')',
#    'was',
#    'a',
#    'German',
#    'politician',
#    '(',
#    'Zentrum',
#    ',',
#    'CVP',
#    ',',
#    'CDU',
#    ')',
#    'and',
#    'Minister',
#    'President',
#    'of',
#    'Saarland',
#    '(',
#    '1956',
#    '-',
#    '1957',
#    ')',
#    '.'],
#   'h': ['hubert ney', 'Q896005', [[0, 1]]],
#   't': ['zentrum', 'Q157537', [[16]]]},
#  {'tokens': ['The',
#    'military',
#    'had',
#    'successfully',
#    'challenged',
#    'the',
#    'Islamic',
#    'Welfare',
#    'Party',
#    'in',
#    '1996',
#    ',',
#    'overthrowing',
#    'the',
#    'government',
#    'of',
#    'prime',
#    'minister',
#    'Necmettin',
#    'Erbakan',
#    'following',
#    'the',
#    'months',
#    '-',
#    'long',
#    'struggle',
#    'known',
#    'as',
#    'the',
#    'February',
#    '28',
#    'process',
#    '.'],
#   'h': ['necmettin erbakan', 'Q243550', [[18, 19]]],
#   't': ['welfare party', 'Q920212', [[7, 8]]]},
#  {'tokens': ['Rochester',
#    'and',
#    'Strood',
#    'is',
#    'a',
#    'constituency',
#    'represented',
#    'in',
#    'the',
#    'House',
#    'of',
#    'Commons',
#    'of',
#    'the',
#    'UK',
#    'Parliament',
#    'since',
#    '2015',
#    'by',
#    'Kelly',
#    'Tolhurst',
#    ',',
#    'a',
#    'Conservative',
#    '.'],
#   'h': ['kelly tolhurst', 'Q20055581', [[19, 20]]],
#   't': ['conservative', 'Q9626', [[23]]]},
#  {'tokens': ['Al',
#    '-',
#    'Radi',
#    "'s",
#    'moderate',
#    'approach',
#    'was',
#    'similar',
#    'to',
#    'that',
#    'of',
#    'Khalid',
#    'Bakdash',
#    ',',
#    'secretary',
#    'of',
#    'the',
#    'Syrian',
#    'Communist',
#    'Party',
#    'and',
#    'elder',
#    'statesman',
#    'of',
#    'Arab',
#    'communism',
#    '.'],
#   'h': ['khalid bakdash', 'Q968674', [[11, 12]]],
#   't': ['syrian communist party', 'Q1957214', [[17, 18, 19]]]},
#  {'tokens': ['In',
#    '1992',
#    ',',
#    'her',
#    'Republican',
#    'opponent',
#    'was',
#    'real',
#    'estate',
#    'broker',
#    'Zach',
#    'Wamp',
#    '.'],
#   'h': ['zach wamp', 'Q139389', [[10, 11]]],
#   't': ['republican', 'Q29468', [[4]]]},
#  {'tokens': ['It',
#    'is',
#    'currently',
#    'represented',
#    'by',
#    'Chuck',
#    'Winder',
#    ',',
#    'Republican',
#    'of',
#    'Boise',
#    ',',
#    'Joe',
#    'Palmer',
#    ',',
#    'Republican',
#    'of',
#    'Meridian',
#    ',',
#    'and',
#    'James',
#    'Holtzclaw',
#    ',',
#    'Republican',
#    'of',
#    'Meridian',
#    '.'],
#   'h': ['james holtzclaw', 'Q16226151', [[20, 21]]],
#   't': ['republican', 'Q29468', [[8], [15], [23]]]},
#  {'tokens': ['Michèle',
#    'Tabarot',
#    'is',
#    'a',
#    'first',
#    '-',
#    'time',
#    'Union',
#    'for',
#    'UDF',
#    '-',
#    'DL',
#    'candidate',
#    'in',
#    'the',
#    '1997',
#    'legislative',
#    'elections',
#    'in',
#    'the',
#    '9th',
#    'constituency',
#    'of',
#    'Alpes',
#    '-',
#    'Maritimes',
#    ',',
#    'but',
#    'she',
#    'is',
#    'beaten',
#    'in',
#    'the',
#    'first',
#    'round',
#    '.'],
#   'h': ['michèle tabarot', 'Q2254052', [[0, 1]]],
#   't': ['udf', 'Q827415', [[9]]]},
#  {'tokens': ['Roy',
#    'Cullen',
#    ',',
#    'PC',
#    '(',
#    'born',
#    'December',
#    '31',
#    ',',
#    '1944',
#    'in',
#    'Montreal',
#    ',',
#    'Quebec',
#    ')',
#    'was',
#    'a',
#    'Liberal',
#    'MP',
#    'for',
#    'the',
#    'riding',
#    'of',
#    'Etobicoke',
#    'North',
#    'in',
#    'the',
#    'House',
#    'of',
#    'Commons',
#    'of',
#    'Canada',
#    '.'],
#   'h': ['roy cullen', 'Q3445764', [[0, 1]]],
#   't': ['liberal', 'Q138345', [[17]]]},
#  {'tokens': ['The',
#    'current',
#    'Leader',
#    'of',
#    'the',
#    'Opposition',
#    'is',
#    'Rui',
#    'Rio',
#    ',',
#    'since',
#    '18',
#    'February',
#    '2018',
#    ',',
#    'after',
#    'having',
#    'been',
#    'elected',
#    'President',
#    'of',
#    'the',
#    'Social',
#    'Democratic',
#    'Party',
#    'on',
#    'the',
#    'previous',
#    '13',
#    'January',
#    '.'],
#   'h': ['rui rio', 'Q7378729', [[7, 8]]],
#   't': ['social democratic party', 'Q595575', [[22, 23, 24]]]},
#  {'tokens': ['Jon',
#    'Olav',
#    'Alstad',
#    '(',
#    'born',
#    '9',
#    'August',
#    '1968',
#    ')',
#    'is',
#    'a',
#    'Norwegian',
#    'politician',
#    'for',
#    'the',
#    'Labour',
#    'Party',
#    '.'],
#   'h': ['jon olav alstad', 'Q11825290', [[0, 1, 2]]],
#   't': ['labour party', 'Q190219', [[15, 16]]]},
#  {'tokens': ['Mahabub',
#    'Ara',
#    'Begum',
#    'Gini',
#    'is',
#    'a',
#    'Bangladesh',
#    'Awami',
#    'League',
#    'politician',
#    ',',
#    'Member',
#    'of',
#    'Parliament',
#    ',',
#    'and',
#    'a',
#    'whip',
#    'in',
#    'the',
#    'parliament',
#    '.'],
#   'h': ['mahabub ara begum gini', 'Q42398738', [[0, 1, 2, 3]]],
#   't': ['bangladesh awami league', 'Q1281480', [[6, 7, 8]]]},
#  {'tokens': ['Bean',
#    'opted',
#    'to',
#    'run',
#    'in',
#    'the',
#    'newly',
#    'created',
#    'district',
#    ',',
#    'and',
#    'faced',
#    'State',
#    'Representative',
#    'Mike',
#    'Weinstein',
#    'in',
#    'the',
#    'Republican',
#    'primary',
#    '.'],
#   'h': ['mike weinstein', 'Q6849241', [[14, 15]]],
#   't': ['republican', 'Q29468', [[18]]]},
#  {'tokens': ['His',
#    'daughter',
#    'Mary',
#    'Fitzpatrick',
#    ',',
#    'a',
#    'Fianna',
#    'Fáil',
#    'member',
#    'of',
#    'Dublin',
#    'City',
#    'Council',
#    ',',
#    'was',
#    'one',
#    'of',
#    'three',
#    'Fianna',
#    'Fáil',
#    'candidates',
#    'in',
#    'Dublin',
#    'Central',
#    'for',
#    'the',
#    '2007',
#    'general',
#    'election',
#    '.'],
#   'h': ['mary fitzpatrick', 'Q6779551', [[2, 3]]],
#   't': ['fianna fáil', 'Q216517', [[6, 7], [18, 19]]]},
#  {'tokens': ['Stanford',
#    ',',
#    'Calif',
#    ':',
#    'Stanford',
#    'University',
#    'Press',
#    ',',
#    '1959',
#    '.',
#    'p.',
#    '33',
#    'Thakin',
#    'Tin',
#    'Mya',
#    'and',
#    'six',
#    'members',
#    'of',
#    'the',
#    'Communist',
#    'Party',
#    'of',
#    'Burma',
#    'sided',
#    'with',
#    'Thakin',
#    'Soe',
#    "'s",
#    'new',
#    'party',
#    '.',
#    'Lintner',
#    ',',
#    'Bertil',
#    '.'],
#   'h': ['thakin tin mya', 'Q7709373', [[12, 13, 14]]],
#   't': ['communist party of burma', 'Q777074', [[20, 21, 22, 23]]]},
#  {'tokens': ['After',
#    'the',
#    'Lithuanian',
#    'presidential',
#    'election',
#    ',',
#    '1993',
#    ',',
#    'the',
#    'newly',
#    'elected',
#    'President',
#    'Algirdas',
#    'Brazauskas',
#    'appointed',
#    'Adolfas',
#    'Šleževičius',
#    'of',
#    'the',
#    'Democratic',
#    'Labour',
#    'Party',
#    'of',
#    'Lithuania',
#    'as',
#    'the',
#    'Prime',
#    'Minister',
#    'on',
#    '10',
#    'March',
#    '1993',
#    '.'],
#   'h': ['adolfas šleževičius', 'Q364965', [[15, 16]]],
#   't': ['democratic labour party of lithuania',
#    'Q63755',
#    [[19, 20, 21, 22, 23]]]},
#  {'tokens': ['In',
#    '2011',
#    ',',
#    'Conservative',
#    'Peter',
#    'Penashue',
#    'defeated',
#    'sitting',
#    'Liberal',
#    'MP',
#    'Todd',
#    'Russell',
#    'by',
#    '79',
#    'votes',
#    ',',
#    'making',
#    'Labrador',
#    'one',
#    'of',
#    'the',
#    'closest',
#    'races',
#    'in',
#    'that',
#    'election',
#    '.'],
#   'h': ['peter penashue', 'Q7176342', [[4, 5]]],
#   't': ['conservative', 'Q488523', [[3]]]},
#  {'tokens': ['He',
#    'was',
#    'defeated',
#    'in',
#    'his',
#    'bid',
#    'for',
#    're',
#    '-',
#    'election',
#    'by',
#    'Democrat',
#    'Jim',
#    'Sullivan',
#    '.'],
#   'h': ['jim sullivan', 'Q16197284', [[12, 13]]],
#   't': ['democrat', 'Q29552', [[11]]]},
#  {'tokens': ['Latham',
#    'became',
#    'leader',
#    'of',
#    'the',
#    'Labor',
#    'Party',
#    'in',
#    'December',
#    '2003',
#    ',',
#    'following',
#    'Simon',
#    'Crean',
#    "'s",
#    'resignation',
#    ',',
#    'when',
#    'he',
#    'narrowly',
#    'defeated',
#    'Kim',
#    'Beazley',
#    'in',
#    'a',
#    'leadership',
#    'election',
#    '.'],
#   'h': ['simon crean', 'Q1400580', [[12, 13]]],
#   't': ['labor party', 'Q216082', [[5, 6]]]},
#  {'tokens': ['Cathers',
#    'was',
#    're',
#    '-',
#    'elected',
#    'in',
#    'the',
#    '1958',
#    'election',
#    ',',
#    'but',
#    'defeated',
#    'by',
#    'John',
#    'Addison',
#    'of',
#    'the',
#    'Liberal',
#    'party',
#    'in',
#    'the',
#    '1962',
#    'election',
#    '.'],
#   'h': ['john addison', 'Q6239626', [[13, 14]]],
#   't': ['liberal party', 'Q138345', [[17, 18]]]},
#  {'tokens': ['Lawrence',
#    'stood',
#    'down',
#    'from',
#    'Parliament',
#    'at',
#    'the',
#    '2005',
#    'general',
#    'election',
#    ',',
#    'at',
#    'which',
#    'the',
#    'Preseli',
#    'Pembrokeshire',
#    'seat',
#    'was',
#    'gained',
#    'by',
#    'the',
#    'Conservative',
#    "'s",
#    'Stephen',
#    'Crabb',
#    '.'],
#   'h': ['stephen crabb', 'Q291393', [[23, 24]]],
#   't': ['conservative', 'Q9626', [[21]]]},
#  {'tokens': ['Its',
#    'opponents',
#    'included',
#    'the',
#    'Conservative',
#    'William',
#    'Joynson',
#    '-',
#    'Hicks',
#    ',',
#    'then',
#    'MP',
#    'for',
#    'Twickenham',
#    'and',
#    'Home',
#    'Secretary',
#    '.'],
#   'h': ['william joynson-hicks', 'Q330604', [[5, 6, 7, 8]]],
#   't': ['conservative', 'Q9626', [[4]]]},
#  {'tokens': ['In',
#    'Brown',
#    "'s",
#    'first',
#    'term',
#    ',',
#    'the',
#    'district',
#    ',',
#    'a',
#    'variation',
#    'of',
#    'what',
#    'is',
#    'now',
#    'District',
#    '35',
#    ',',
#    'represented',
#    'by',
#    'Republican',
#    'Robert',
#    'Kostelka',
#    ',',
#    'also',
#    'included',
#    'Morehouse',
#    'Parish',
#    '.'],
#   'h': ['robert kostelka', 'Q7346447', [[21, 22]]],
#   't': ['republican', 'Q29468', [[20]]]},
#  {'tokens': ['In',
#    '2015',
#    ',',
#    'the',
#    'sitting',
#    'SNP',
#    'MP',
#    'Stewart',
#    'Hosie',
#    'retained',
#    'the',
#    'seat',
#    'with',
#    'a',
#    'majority',
#    'of',
#    '19,162',
#    'votes',
#    'and',
#    'a',
#    '39.8',
#    '%',
#    'share',
#    'of',
#    'the',
#    'vote',
#    '.'],
#   'h': ['stewart hosie', 'Q689514', [[7, 8]]],
#   't': ['snp', 'Q10658', [[5]]]},
#  {'tokens': ['After',
#    'his',
#    'unsuccessful',
#    'candidacy',
#    'in',
#    'the',
#    '2004',
#    'European',
#    'Parliament',
#    'election',
#    ',',
#    'Kronberger',
#    'contested',
#    'his',
#    'fellow',
#    'Freedom',
#    'Party',
#    'of',
#    'Austria',
#    'member',
#    ',',
#    'Andreas',
#    'Mölzer',
#    "'s",
#    'election',
#    'in',
#    'the',
#    'Constitutional',
#    'Court',
#    'of',
#    'Austria',
#    '.'],
#   'h': ['andreas mölzer', 'Q79068', [[21, 22]]],
#   't': ['freedom party of austria', 'Q131692', [[15, 16, 17, 18]]]},
#  {'tokens': ['Gjems',
#    '-',
#    'Onstad',
#    'praised',
#    'Progress',
#    'Party',
#    'MPs',
#    'Vidar',
#    'Kleppe',
#    'and',
#    'Øystein',
#    'Hedstrøm',
#    'at',
#    'their',
#    'election',
#    'campaign',
#    'rally',
#    'in',
#    '1999',
#    ',',
#    'and',
#    'participated',
#    'in',
#    'the',
#    'non',
#    '-',
#    'partisan',
#    'demonstration',
#    'against',
#    'Muslim',
#    'prayer',
#    'calling',
#    'in',
#    '2000',
#    '.'],
#   'h': ['øystein hedstrøm', 'Q8079322', [[10, 11]]],
#   't': ['progress party', 'Q485665', [[4, 5]]]},
#  {'tokens': ['It',
#    'is',
#    'currently',
#    'represented',
#    'by',
#    'Cathy',
#    'Sproule',
#    'of',
#    'the',
#    'Saskatchewan',
#    'New',
#    'Democratic',
#    'Party',
#    ',',
#    'first',
#    'elected',
#    'in',
#    '2011',
#    '.'],
#   'h': ['cathy sproule', 'Q5053496', [[5, 6]]],
#   't': ['saskatchewan new democratic party', 'Q1661160', [[9, 10, 11, 12]]]},
#  {'tokens': ['Paul',
#    'Scheffer',
#    'is',
#    'also',
#    'a',
#    'prominent',
#    'member',
#    'of',
#    'the',
#    'Dutch',
#    'Labour',
#    'Party',
#    '.'],
#   'h': ['paul scheffer', 'Q2062204', [[0, 1]]],
#   't': ['dutch labour party', 'Q275441', [[9, 10, 11]]]},
#  {'tokens': ['She',
#    'lost',
#    'the',
#    'seat',
#    'to',
#    'Sir',
#    'Herbert',
#    'Raymond',
#    'Gower',
#    '(',
#    'Conservative',
#    ')',
#    'at',
#    'the',
#    '1951',
#    'general',
#    'election',
#    '.'],
#   'h': ['sir herbert raymond gower', 'Q7298808', [[5, 6, 7, 8]]],
#   't': ['conservative', 'Q9626', [[10]]]},
#  {'tokens': ['Peruvian',
#    'president',
#    'Luis',
#    'Miguel',
#    'Sánchez',
#    'Cerro',
#    'founded',
#    'the',
#    'Revolutionary',
#    'Union',
#    'in',
#    '1931',
#    'as',
#    'the',
#    'state',
#    'party',
#    'for',
#    'his',
#    'dictatorship',
#    '.'],
#   'h': ['luis miguel sánchez cerro', 'Q128998', [[2, 3, 4, 5]]],
#   't': ['revolutionary union', 'Q6157100', [[8, 9]]]},
#  {'tokens': ['Opposition',
#    'leader',
#    'Sushil',
#    'Kumar',
#    'Modi',
#    'of',
#    'the',
#    'Bharatiya',
#    'Janata',
#    'Party',
#    'called',
#    'Manjhi',
#    'a',
#    '"',
#    'dummy',
#    'chief',
#    'minister',
#    '"',
#    ',',
#    'to',
#    'which',
#    'Manjhi',
#    'responded',
#    'by',
#    'saying',
#    'he',
#    'was',
#    '"',
#    'not',
#    'a',
#    'rubber',
#    'stamp',
#    '.',
#    '"'],
#   'h': ['sushil kumar modi', 'Q7648950', [[2, 3, 4]]],
#   't': ['bharatiya janata party', 'Q10230', [[7, 8, 9]]]},
#  {'tokens': ['MLA',
#    'of',
#    'Burari',
#    '(',
#    'Delhi',
#    'Assembly',
#    'constituency',
#    ')',
#    'is',
#    'Sanjeev',
#    'Jha',
#    'from',
#    'AAP',
#    'since',
#    '2015',
#    '.'],
#   'h': ['sanjeev jha', 'Q16730291', [[9, 10]]],
#   't': ['aap', 'Q129844', [[12]]]},
#  {'tokens': ['After',
#    'their',
#    'release',
#    ',',
#    'many',
#    'of',
#    'the',
#    'prisoners',
#    'jailed',
#    'between',
#    'the',
#    'late',
#    '1940s',
#    'and',
#    'the',
#    'late',
#    '1980s',
#    'went',
#    'on',
#    'to',
#    'establish',
#    'the',
#    'Democratic',
#    'Progressive',
#    'Party',
#    ',',
#    'most',
#    'notably',
#    'Shih',
#    'Ming',
#    '-',
#    'teh',
#    '.'],
#   'h': ['shih ming-teh', 'Q708121', [[28, 29, 30, 31]]],
#   't': ['democratic progressive party', 'Q903822', [[22, 23, 24]]]},
#  {'tokens': ['Pan',
#    'was',
#    'appointed',
#    'director',
#    'of',
#    'the',
#    'National',
#    'Academy',
#    '(',
#    'Zhejiang',
#    'Academy',
#    'of',
#    'Fine',
#    'Arts',
#    ')',
#    'by',
#    'the',
#    'Kuomintang',
#    'Minister',
#    'of',
#    'Culture',
#    'Chen',
#    'Lifu',
#    'in',
#    '1945',
#    '.'],
#   'h': ['chen lifu', 'Q698368', [[21, 22]]],
#   't': ['kuomintang', 'Q31113', [[17]]]},
#  {'tokens': ['A',
#    'fifth',
#    'former',
#    'Prime',
#    'Minister',
#    ',',
#    'Ivars',
#    'Godmanis',
#    ',',
#    'joined',
#    'the',
#    'Latvian',
#    'Way',
#    'party',
#    'after',
#    'his',
#    'term',
#    'as',
#    'Prime',
#    'Minister',
#    'ended',
#    '.'],
#   'h': ['ivars godmanis', 'Q210822', [[6, 7]]],
#   't': ['latvian way', 'Q1507032', [[11, 12]]]},
#  {'tokens': ['On',
#    '11',
#    'January',
#    ',',
#    'Shiv',
#    'Sena',
#    'MLA',
#    'Subhash',
#    'Desai',
#    'sent',
#    'a',
#    'letter',
#    'to',
#    'Chief',
#    'Minister',
#    'Chavan',
#    'opposing',
#    'the',
#    'Reliance',
#    'Metro',
#    'name',
#    ',',
#    'and',
#    'expressing',
#    'support',
#    'for',
#    'the',
#    'name',
#    'Mumbai',
#    'Metro',
#    '.'],
#   'h': ['subhash desai', 'Q17180565', [[7, 8]]],
#   't': ['shiv sena', 'Q59177', [[4, 5]]]},
#  {'tokens': ['However',
#    ',',
#    'Conservative',
#    'candidate',
#    'Paul',
#    'Davies',
#    'won',
#    'the',
#    'seat',
#    ',',
#    'defeating',
#    'Tamsin',
#    'Dunwoody',
#    ',',
#    'the',
#    'Welsh',
#    'Labour',
#    'incumbent',
#    '.'],
#   'h': ['tamsin dunwoody', 'Q7681863', [[11, 12]]],
#   't': ['welsh labour', 'Q832685', [[15, 16]]]},
#  {'tokens': ['He',
#    'served',
#    'as',
#    'Prime',
#    'Minister',
#    'of',
#    'Madagascar',
#    'from',
#    'March',
#    'to',
#    'September',
#    '2009',
#    'immediately',
#    'following',
#    'the',
#    'successful',
#    'March',
#    '2009',
#    'coup',
#    "d'etat",
#    'led',
#    'by',
#    'Andry',
#    'Rajoelina',
#    'of',
#    'the',
#    'Young',
#    'Malagasies',
#    'Determined',
#    'political',
#    'party',
#    '.'],
#   'h': ['andry rajoelina', 'Q57363', [[22, 23]]],
#   't': ['young malagasies determined', 'Q8058262', [[26, 27, 28]]]},
#  {'tokens': ['Six',
#    'Democratic',
#    'members',
#    'of',
#    'the',
#    'House',
#    'of',
#    'Representatives',
#    ',',
#    'including',
#    'Jewish',
#    'representatives',
#    'Jan',
#    'Schakowsky',
#    ',',
#    'Jerrold',
#    'Nadler',
#    ',',
#    'John',
#    'Yarmuth',
#    ',',
#    'and',
#    'Steve',
#    'Cohen',
#    ',',
#    'urged',
#    'their',
#    'colleagues',
#    'in',
#    'the',
#    'Senate',
#    'to',
#    'vote',
#    'against',
#    'Friedman',
#    '.'],
#   'h': ['john yarmuth', 'Q699970', [[18, 19]]],
#   't': ['democratic', 'Q29552', [[1]]]},
#  {'tokens': ['The',
#    'pro',
#    '-',
#    'Beijing',
#    'ICT',
#    'Energy',
#    'including',
#    'DAB',
#    'member',
#    'Elizabeth',
#    'Quat',
#    'got',
#    'only',
#    '8',
#    'of',
#    'the',
#    '24',
#    'members',
#    'elected',
#    '.'],
#   'h': ['elizabeth quat', 'Q5363394', [[9, 10]]],
#   't': ['dab', 'Q21916', [[7]]]},
#  {'tokens': ['Following',
#    'the',
#    'announcement',
#    'of',
#    'the',
#    'election',
#    'result',
#    'in',
#    '2001',
#    ',',
#    'Harold',
#    'Hird',
#    ',',
#    'a',
#    'Liberal',
#    'Party',
#    'candidate',
#    'in',
#    'the',
#    'electorate',
#    'of',
#    'Ginninderra',
#    ',',
#    'sought',
#    'a',
#    'recount',
#    'of',
#    'the',
#    'votes',
#    'in',
#    'that',
#    'electorate',
#    '.'],
#   'h': ['harold hird', 'Q5661046', [[10, 11]]],
#   't': ['liberal party', 'Q241149', [[14, 15]]]},
#  {'tokens': ['Nine',
#    'initial',
#    'leadership',
#    'candidates',
#    'include',
#    'PASOK',
#    'leader',
#    'Fofi',
#    'Gennimata',
#    ',',
#    'The',
#    'River',
#    'leader',
#    'Stavros',
#    'Theodorakis',
#    'and',
#    'incumbent',
#    'Athens',
#    'mayor',
#    'Giorgos',
#    'Kaminis',
#    '.'],
#   'h': ['fofi gennimata', 'Q12885954', [[7, 8]]],
#   't': ['pasok', 'Q203934', [[5]]]},
#  {'tokens': ['On',
#    'becoming',
#    'leader',
#    'of',
#    'Labour',
#    'in',
#    'the',
#    'Scottish',
#    'Parliament',
#    'in',
#    'September',
#    '2008',
#    ',',
#    'Iain',
#    'Gray',
#    'appointed',
#    'McNulty',
#    'Shadow',
#    'Minister',
#    'for',
#    'Transport',
#    ',',
#    'Infrastructure',
#    'and',
#    'Climate',
#    'Change',
#    '.'],
#   'h': ['iain gray', 'Q1421398', [[13, 14]]],
#   't': ['labour', 'Q9630', [[4]]]},
#  {'tokens': ['The',
#    'Luton',
#    'Town',
#    'chairman',
#    ',',
#    'Conservative',
#    'Member',
#    'of',
#    'Parliament',
#    'David',
#    'Evans',
#    ',',
#    'reacted',
#    'by',
#    'imposing',
#    'a',
#    'ban',
#    'on',
#    'all',
#    'away',
#    'supporters',
#    'from',
#    'Kenilworth',
#    'Road',
#    'from',
#    'the',
#    'start',
#    'of',
#    'the',
#    '1986–87',
#    'season',
#    '.'],
#   'h': ['david evans', 'Q5233457', [[9, 10]]],
#   't': ['conservative', 'Q9626', [[5]]]},
#  {'tokens': ['Senators',
#    'expressing',
#    'support',
#    'for',
#    'Zinke',
#    "'s",
#    'confirmation',
#    'was',
#    'Democratic',
#    'Sen.',
#    'Jon',
#    'Tester',
#    'from',
#    'Montana',
#    '.'],
#   'h': ['jon tester', 'Q529351', [[10, 11]]],
#   't': ['democratic', 'Q29552', [[8]]]},
#  {'tokens': ['Alexander',
#    'De',
#    'Croo',
#    ',',
#    'the',
#    'son',
#    'of',
#    'former',
#    'speaker',
#    'of',
#    'the',
#    'Belgian',
#    'parliament',
#    'Herman',
#    'De',
#    'Croo',
#    ',',
#    'ran',
#    'for',
#    'the',
#    'leadership',
#    'of',
#    'his',
#    'father',
#    "'s",
#    'party',
#    'Open',
#    'VLD',
#    'at',
#    'age',
#    '33',
#    '.'],
#   'h': ['herman de croo', 'Q1351926', [[13, 14, 15]]],
#   't': ['open vld', 'Q1160192', [[26, 27]]]},
#  {'tokens': ['Simon',
#    'Emil',
#    'Ammitzbøll',
#    '(',
#    'born',
#    '20',
#    'October',
#    '1977',
#    'in',
#    'Hillerød',
#    ')',
#    'is',
#    'a',
#    'Danish',
#    'politician',
#    ',',
#    'and',
#    'member',
#    'of',
#    'the',
#    'Parliament',
#    'of',
#    'Denmark',
#    'for',
#    'the',
#    'classical',
#    'liberal',
#    'party',
#    'Liberal',
#    'Alliance',
#    '.'],
#   'h': ['simon emil ammitzbøll', 'Q952472', [[0, 1, 2]]],
#   't': ['liberal alliance', 'Q478180', [[28, 29]]]},
#  {'tokens': ['In',
#    '1880',
#    'he',
#    'was',
#    'elected',
#    'as',
#    'Liberal',
#    'member',
#    'of',
#    'parliament',
#    'for',
#    'Stalybridge',
#    ',',
#    'unseating',
#    'the',
#    'sitting',
#    'Conservative',
#    'MP',
#    ',',
#    'Tom',
#    'Harrop',
#    'Sidebottom',
#    '.'],
#   'h': ['tom harrop sidebottom', 'Q7816107', [[19, 20, 21]]],
#   't': ['conservative', 'Q9626', [[16]]]},
#  {'tokens': ['Sokoloski',
#    'was',
#    'narrowly',
#    'defeated',
#    'in',
#    'the',
#    '1999',
#    'provincial',
#    'election',
#    ',',
#    'receiving',
#    '20,210',
#    'votes',
#    '(',
#    '44.86',
#    '%',
#    ')',
#    'against',
#    'Liberal',
#    'Dave',
#    'Levac',
#    "'s",
#    '21,116',
#    '(',
#    '46.98',
#    '%',
#    ')',
#    '.'],
#   'h': ['dave levac', 'Q5229182', [[19, 20]]],
#   't': ['liberal', 'Q1553186', [[18]]]},
#  {'tokens': ['Following',
#    'Tyler',
#    "'s",
#    'veto',
#    'of',
#    'several',
#    'Whig',
#    'banking',
#    'bills',
#    ',',
#    'in',
#    'September',
#    '1841',
#    'all',
#    'the',
#    'members',
#    'of',
#    'the',
#    'cabinet',
#    'except',
#    'Secretary',
#    'of',
#    'State',
#    'Daniel',
#    'Webster',
#    'resigned',
#    'in',
#    'protest',
#    ',',
#    'a',
#    'maneuver',
#    'that',
#    'Clay',
#    'had',
#    'engineered',
#    '.'],
#   'h': ['daniel webster', 'Q106231', [[23, 24]]],
#   't': ['whig', 'Q42183', [[6]]]},
#  {'tokens': ['Smith',
#    'was',
#    'elected',
#    'to',
#    'the',
#    'Assembly',
#    'in',
#    '1916',
#    'for',
#    'the',
#    'Clark',
#    'County',
#    'district',
#    'to',
#    'succeed',
#    'fellow',
#    'Republican',
#    'Emery',
#    'Crosby',
#    ',',
#    'receiving',
#    '3482',
#    'votes',
#    'to',
#    '1201',
#    'for',
#    'Democrat',
#    'Alvin',
#    'Foster',
#    '.'],
#   'h': ['emery crosby', 'Q15997474', [[17, 18]]],
#   't': ['republican', 'Q29468', [[16]]]},
#  {'tokens': ['The',
#    'main',
#    'opposition',
#    'party',
#    'is',
#    'Raffi',
#    'Hovannisian',
#    "'s",
#    'Heritage',
#    'party',
#    ',',
#    'which',
#    'favours',
#    'eventual',
#    'Armenian',
#    'membership',
#    'in',
#    'the',
#    'European',
#    'Union',
#    'and',
#    'NATO',
#    '.'],
#   'h': ['raffi hovannisian', 'Q2389114', [[5, 6]]],
#   't': ['heritage', 'Q1348278', [[8]]]},
#  {'tokens': ['Incumbent',
#    'Mayor',
#    'Carl',
#    'Brewer',
#    ',',
#    'a',
#    'Democrat',
#    ',',
#    'was',
#    'term',
#    '-',
#    'limited',
#    'and',
#    'could',
#    'not',
#    'seek',
#    'a',
#    'third',
#    'term',
#    'in',
#    'office',
#    '.'],
#   'h': ['carl brewer', 'Q5039939', [[2, 3]]],
#   't': ['democrat', 'Q29552', [[6]]]},
#  {'tokens': ['He',
#    'is',
#    'the',
#    'son',
#    'of',
#    'Chief',
#    'Minister',
#    'of',
#    'Andhra',
#    'Pradesh',
#    'and',
#    'Telugu',
#    'Desam',
#    'Party',
#    'Chief',
#    'Nara',
#    'Chandrababu',
#    'Naidu',
#    ',',
#    'and',
#    'grandson',
#    'of',
#    'former',
#    'Chief',
#    'Minister',
#    'of',
#    'Andhra',
#    'Pradesh',
#    'Sri',
#    'N.',
#    'T.',
#    'Rama',
#    'Rao',
#    '.'],
#   'h': ['nara chandrababu naidu', 'Q3518013', [[15, 16, 17]]],
#   't': ['telugu desam party', 'Q2279320', [[11, 12, 13]]]},
#  {'tokens': ['Alex',
#    'Cunningham',
#    ',',
#    'the',
#    'Labour',
#    'MP',
#    'for',
#    'Stockton',
#    'North',
#    'said',
#    'he',
#    'was',
#    '"',
#    'deeply',
#    'disappointed',
#    '"',
#    'that',
#    'the',
#    'series',
#    'was',
#    'being',
#    'filmed',
#    'there',
#    '.'],
#   'h': ['alex cunningham', 'Q291649', [[0, 1]]],
#   't': ['labour', 'Q9630', [[4]]]},
#  {'tokens': ['PQ',
#    'star',
#    'candidate',
#    'and',
#    'Bloc',
#    'Québécois',
#    '(',
#    'BQ',
#    ')',
#    'Member',
#    'of',
#    'Parliament',
#    'Michel',
#    'Bellehumeur',
#    'finished',
#    'second',
#    'with',
#    '32',
#    '%',
#    'of',
#    'the',
#    'vote',
#    '.'],
#   'h': ['michel bellehumeur', 'Q3308981', [[12, 13]]],
#   't': ['bloc québécois', 'Q735105', [[4, 5]]]},
#  {'tokens': ['This',
#    'party',
#    'had',
#    'been',
#    'founded',
#    'in',
#    '1875',
#    'by',
#    'merging',
#    'two',
#    'previous',
#    'parties',
#    ':',
#    'the',
#    'ADAV',
#    'formed',
#    'by',
#    'Ferdinand',
#    'Lassalle',
#    'and',
#    'the',
#    'SDAP',
#    'of',
#    'August',
#    'Bebel',
#    'and',
#    'Wilhelm',
#    'Liebknecht',
#    '.'],
#   'h': ['august bebel', 'Q76520', [[23, 24]]],
#   't': ['sdap', 'Q565429', [[21]]]},
#  {'tokens': ['Labor',
#    'Senators',
#    'Gordon',
#    'Brown',
#    ',',
#    'Joe',
#    'Collings',
#    'and',
#    'Ben',
#    'Courtice',
#    'were',
#    'not',
#    'up',
#    'for',
#    're',
#    '-',
#    'election',
#    '.'],
#   'h': ['gordon brown', 'Q8853537', [[2, 3]]],
#   't': ['labor', 'Q216082', [[0]]]},
#  {'tokens': ['Like',
#    'most',
#    'former',
#    'ISK',
#    'members',
#    'in',
#    'Germany',
#    ',',
#    'Gustav',
#    'Heckmann',
#    'joined',
#    'the',
#    'no',
#    'longer',
#    'banned',
#    'SPD',
#    '.'],
#   'h': ['gustav heckmann', 'Q1244480', [[8, 9]]],
#   't': ['isk', 'Q882940', [[3]]]},
#  {'tokens': ['His',
#    'main',
#    'opponent',
#    'was',
#    'then',
#    'Prime',
#    'Minister',
#    'and',
#    'PSD',
#    'president',
#    'Adrian',
#    'Năstase',
#    '.'],
#   'h': ['adrian năstase', 'Q271966', [[10, 11]]],
#   't': ['psd', 'Q752435', [[8]]]},
#  {'tokens': ['In',
#    ',',
#    'Hudson',
#    'was',
#    'unexpectedly',
#    'beaten',
#    'by',
#    '24-year',
#    '-',
#    'old',
#    'George',
#    'Black',
#    'of',
#    'the',
#    'United',
#    'Party',
#    '.'],
#   'h': ['george black', 'Q5537013', [[10, 11]]],
#   't': ['united party', 'Q2495287', [[14, 15]]]},
#  {'tokens': ['Republican',
#    'Party',
#    'of',
#    'Minnesota',
#    'candidate',
#    'Harold',
#    'Levander',
#    'defeated',
#    'Minnesota',
#    'Democratic',
#    '–',
#    'Farmer',
#    '–',
#    'Labor',
#    'Party',
#    'challenger',
#    'Karl',
#    'Rolvaag',
#    '.'],
#   'h': ['harold levander', 'Q650029', [[5, 6]]],
#   't': ['republican party of minnesota', 'Q7314659', [[0, 1, 2, 3]]]},
#  {'tokens': ['While',
#    'Barnes',
#    'lost',
#    'his',
#    'seat',
#    'in',
#    '1857',
#    ',',
#    'Crook',
#    'was',
#    'again',
#    'successful',
#    ',',
#    'being',
#    'returned',
#    'with',
#    'the',
#    'Conservative',
#    'William',
#    'Gray',
#    '.'],
#   'h': ['william gray', 'Q8010128', [[18, 19]]],
#   't': ['conservative', 'Q9626', [[17]]]},
#  {'tokens': ['In',
#    '2012',
#    ',',
#    'with',
#    'incumbent',
#    'Republican',
#    'Representative',
#    'Jerry',
#    'Weiers',
#    'retiring',
#    'and',
#    'Steve',
#    'Montenegro',
#    'redistricted',
#    'to',
#    'District',
#    '13',
#    ',',
#    'Petersen',
#    'ran',
#    'in',
#    'the',
#    'three',
#    '-',
#    'way',
#    'August',
#    '28',
#    ',',
#    '2012',
#    ',',
#    'Republican',
#    'primary',
#    '.'],
#   'h': ['steve montenegro', 'Q7613407', [[11, 12]]],
#   't': ['republican', 'Q29468', [[5], [30]]]},
#  {'tokens': ['The',
#    'Liberal',
#    'Party',
#    'led',
#    'by',
#    'Lemuel',
#    'John',
#    'Tweedie',
#    'formed',
#    'the',
#    'government',
#    '.'],
#   'h': ['lemuel john tweedie', 'Q3229400', [[5, 6, 7]]],
#   't': ['liberal party', 'Q2867848', [[1, 2]]]},
#  {'tokens': ['Republican',
#    'Congressman',
#    'Wayne',
#    'Allard',
#    'won',
#    'the',
#    'open',
#    'seat',
#    ',',
#    'beating',
#    'Democrat',
#    'Tom',
#    'Strickland',
#    ',',
#    'attorney',
#    'and',
#    'former',
#    'U.S.',
#    'Attorney',
#    'for',
#    'the',
#    'District',
#    'of',
#    'Colorado',
#    '.'],
#   'h': ['tom strickland', 'Q16981525', [[11, 12]]],
#   't': ['democrat', 'Q29552', [[10]]]},
#  {'tokens': ['The',
#    'Symington',
#    'Amendment',
#    'is',
#    'legislation',
#    'introduced',
#    'by',
#    'Stuart',
#    'Symington',
#    ',',
#    'a',
#    'Democratic',
#    'senator',
#    'from',
#    'Missouri',
#    ',',
#    'authored',
#    'to',
#    'strengthen',
#    'the',
#    'US',
#    'position',
#    'on',
#    'nuclear',
#    'non',
#    '-',
#    'proliferation',
#    '.'],
#   'h': ['stuart symington', 'Q962660', [[7, 8]]],
#   't': ['democratic', 'Q29552', [[11]]]},
#  {'tokens': ['That',
#    'campaign',
#    'was',
#    'a',
#    'three',
#    'way',
#    'race',
#    'which',
#    'saw',
#    'New',
#    'Democratic',
#    'Party',
#    'leader',
#    'Alexa',
#    'McDonough',
#    'get',
#    'elected',
#    ',',
#    'while',
#    'Donahoe',
#    'finished',
#    'second',
#    ',',
#    'ahead',
#    'of',
#    'Liberal',
#    'incumbent',
#    ',',
#    'Mary',
#    'Clancy',
#    '.'],
#   'h': ['alexa mcdonough', 'Q2604970', [[13, 14]]],
#   't': ['new democratic party', 'Q130765', [[9, 10, 11]]]},
#  {'tokens': ['The',
#    'departing',
#    'representative',
#    ',',
#    'Republican',
#    'Van',
#    'Taylor',
#    ',',
#    'succeeded',
#    'state',
#    'Senator',
#    'Ken',
#    'Paxton',
#    'of',
#    'McKinney',
#    ',',
#    'the',
#    'incoming',
#    'Attorney',
#    'General',
#    'of',
#    'Texas',
#    '.'],
#   'h': ['van taylor', 'Q7913689', [[5, 6]]],
#   't': ['republican', 'Q29468', [[4]]]},
#  {'tokens': ['In',
#    'the',
#    'provincial',
#    'election',
#    'of',
#    '2003',
#    ',',
#    'he',
#    'lost',
#    'to',
#    'Liberal',
#    'candidate',
#    'Peter',
#    'Fonseca',
#    '(',
#    'a',
#    'well',
#    '-',
#    'known',
#    'Olympic',
#    'athlete',
#    ')',
#    'by',
#    'about',
#    '3,000',
#    'votes',
#    ',',
#    'amid',
#    'a',
#    'general',
#    'regional',
#    'decline',
#    'in',
#    'Tory',
#    'support',
#    '.'],
#   'h': ['peter fonseca', 'Q7174026', [[12, 13]]],
#   't': ['liberal', 'Q1553186', [[10]]]},
#  {'tokens': ['Beginning',
#    'in',
#    'the',
#    '1960s',
#    ',',
#    'the',
#    'Democrats',
#    'lost',
#    'their',
#    'dominant',
#    'position',
#    'in',
#    'the',
#    'South',
#    ',',
#    'as',
#    'prominent',
#    'Democrats',
#    'such',
#    'as',
#    'Strom',
#    'Thurmond',
#    'joined',
#    'the',
#    'Republican',
#    'Party',
#    '.'],
#   'h': ['strom thurmond', 'Q324719', [[20, 21]]],
#   't': ['democrats', 'Q29552', [[6], [17]]]},
#  {'tokens': ['Senator',
#    ',',
#    'Vice',
#    'President',
#    'and',
#    '1968',
#    'presidential',
#    'nominee',
#    'Hubert',
#    'Humphrey',
#    'defeated',
#    'Republican',
#    'U.S.',
#    'Representative',
#    'Clark',
#    'MacGregor',
#    '.'],
#   'h': ['clark macgregor', 'Q1095726', [[14, 15]]],
#   't': ['republican', 'Q29468', [[11]]]},
#  {'tokens': ['In',
#    'the',
#    '1997',
#    'election',
#    ',',
#    'the',
#    'PGIB',
#    'gained',
#    'notoriety',
#    'for',
#    'running',
#    'attack',
#    'ads',
#    'against',
#    'Liberal',
#    'candidates',
#    'Sheila',
#    'Copps',
#    'and',
#    'Jane',
#    'Stewart',
#    '.'],
#   'h': ['sheila copps', 'Q276205', [[16, 17]]],
#   't': ['liberal', 'Q138345', [[14]]]},
#  {'tokens': ['Jackson',
#    "'s",
#    'opponents',
#    'in',
#    'the',
#    'Democratic',
#    'primary',
#    'were',
#    'Palmer',
#    ',',
#    'Emil',
#    'Jones',
#    ',',
#    'Monique',
#    'Davis',
#    ',',
#    'and',
#    'John',
#    'Morrow',
#    'in',
#    'the',
#    'Democratic',
#    'primary',
#    ',',
#    'which',
#    'was',
#    'set',
#    'for',
#    'November',
#    '29',
#    ',',
#    '1995',
#    '.'],
#   'h': ['emil jones', 'Q5371307', [[10, 11]]],
#   't': ['democratic', 'Q29552', [[5], [21]]]},
#  {'tokens': ['Following',
#    'the',
#    'election',
#    ',',
#    'the',
#    'Labour',
#    'Party',
#    'and',
#    'the',
#    'Liberal',
#    'Democrats',
#    'formed',
#    'the',
#    'Scottish',
#    'Executive',
#    ',',
#    'with',
#    'Labour',
#    'Member',
#    'of',
#    'the',
#    'Scottish',
#    'Parliament',
#    '(',
#    'MSP',
#    ')',
#    'Donald',
#    'Dewar',
#    'becoming',
#    'First',
#    'Minister',
#    '.'],
#   'h': ['donald dewar', 'Q333158', [[26, 27]]],
#   't': ['labour party', 'Q3179541', [[5, 6]]]},
#  {'tokens': ['Adorno',
#    "'s",
#    'lecture',
#    'is',
#    'often',
#    'seen',
#    'as',
#    'consisting',
#    'in',
#    'part',
#    'of',
#    'a',
#    'variably',
#    'implicit',
#    'and',
#    'explicit',
#    'critique',
#    'of',
#    'the',
#    'work',
#    'of',
#    'Martin',
#    'Heidegger',
#    ',',
#    'whose',
#    'formal',
#    'ties',
#    'to',
#    'the',
#    'Nazi',
#    'Party',
#    'are',
#    'well',
#    'known',
#    '.'],
#   'h': ['martin heidegger', 'Q48301', [[21, 22]]],
#   't': ['nazi party', 'Q7320', [[29, 30]]]},
#  {'tokens': ['In',
#    '1994',
#    ',',
#    'incumbent',
#    'Democrat',
#    'Ted',
#    'Kennedy',
#    'won',
#    're',
#    '-',
#    'election',
#    'against',
#    'businessman',
#    'Mitt',
#    'Romney',
#    'with',
#    'just',
#    '58',
#    '%',
#    'of',
#    'the',
#    'vote',
#    ',',
#    'the',
#    'lowest',
#    'percentage',
#    'since',
#    'his',
#    'first',
#    'senate',
#    'election',
#    'campaign',
#    'in',
#    '1962',
#    '.'],
#   'h': ['ted kennedy', 'Q134549', [[5, 6]]],
#   't': ['democrat', 'Q29552', [[4]]]},
#  {'tokens': ['In',
#    'the',
#    'early',
#    '1960s',
#    'Lord',
#    'Mayor',
#    'Clem',
#    'Jones',
#    'of',
#    'the',
#    'Australian',
#    'Labor',
#    'Party',
#    'embarked',
#    'on',
#    'an',
#    'ambitious',
#    'programme',
#    'to',
#    '"',
#    'sewer',
#    '"',
#    'Brisbane',
#    'and',
#    'within',
#    'five',
#    'years',
#    'all',
#    'the',
#    'residences',
#    'were',
#    'sewered',
#    '.'],
#   'h': ['clem jones', 'Q5131180', [[6, 7]]],
#   't': ['australian labor party', 'Q216082', [[10, 11, 12]]]},
#  {'tokens': ['Randy',
#    'Asbury',
#    '(',
#    'born',
#    'October',
#    '4',
#    ',',
#    '1958',
#    ')',
#    'is',
#    'a',
#    'Republican',
#    'former',
#    'member',
#    'of',
#    'the',
#    'Missouri',
#    'House',
#    'of',
#    'Representatives',
#    '.'],
#   'h': ['randy asbury', 'Q7292067', [[0, 1]]],
#   't': ['republican', 'Q29468', [[11]]]},
#  {'tokens': ['Led',
#    'by',
#    'its',
#    'president',
#    ',',
#    'Artur',
#    'Mas',
#    ',',
#    'on',
#    '8',
#    'July',
#    '2016',
#    'Democratic',
#    'Convergence',
#    'of',
#    'Catalonia',
#    '(',
#    'CDC',
#    'by',
#    'its',
#    'Catalan',
#    'acronym',
#    ')',
#    'held',
#    'its',
#    'last',
#    'congress',
#    '.'],
#   'h': ['artur mas', 'Q8015', [[5, 6]]],
#   't': ['democratic convergence of catalonia',
#    'Q1129443',
#    [[12, 13, 14, 15]]]},
#  {'tokens': ['She',
#    'won',
#    'the',
#    'Democratic',
#    'primary',
#    'unopposed',
#    ',',
#    'and',
#    'advanced',
#    'to',
#    'the',
#    'general',
#    'election',
#    ',',
#    'where',
#    'she',
#    'faced',
#    'Republican',
#    'State',
#    'Representative',
#    'Ellyn',
#    'Setnor',
#    'Bogdanoff',
#    'and',
#    'independent',
#    'candidate',
#    'Miranda',
#    'Rosenberg',
#    '.'],
#   'h': ['ellyn setnor bogdanoff', 'Q5366235', [[20, 21, 22]]],
#   't': ['republican', 'Q29468', [[17]]]},
#  {'tokens': ['In',
#    '1972',
#    ',',
#    'Wade',
#    'got',
#    'into',
#    'an',
#    'open',
#    'dispute',
#    'with',
#    'Democratic',
#    'State',
#    'Representative',
#    'Dorothy',
#    'Mae',
#    'Taylor',
#    'of',
#    'New',
#    'Orleans',
#    ',',
#    'the',
#    'first',
#    'African',
#    '-',
#    'American',
#    'female',
#    'to',
#    'serve',
#    'in',
#    'the',
#    'Louisiana',
#    'legislature',
#    '.'],
#   'h': ['dorothy mae taylor', 'Q18157170', [[13, 14, 15]]],
#   't': ['democratic', 'Q29552', [[10]]]},
#  {'tokens': ['The',
#    'founder',
#    'of',
#    'the',
#    'party',
#    ',',
#    'Heydar',
#    'Aliyev',
#    ',',
#    'was',
#    'a',
#    'member',
#    'of',
#    'the',
#    'Communist',
#    'Party',
#    'of',
#    'the',
#    'Soviet',
#    'Union',
#    'until',
#    'July',
#    '1991',
#    '.'],
#   'h': ['heydar aliyev', 'Q157451', [[6, 7]]],
#   't': ['communist party of the soviet union',
#    'Q79854',
#    [[14, 15, 16, 17, 18, 19]]]},
#  {'tokens': ['The',
#    '29th',
#    'Alberta',
#    'Legislature',
#    'was',
#    'formed',
#    'after',
#    'the',
#    '2015',
#    'election',
#    ',',
#    'during',
#    'which',
#    'the',
#    'New',
#    'Democrats',
#    'won',
#    'their',
#    'first',
#    'majority',
#    'government',
#    'under',
#    'the',
#    'leadership',
#    'of',
#    'Rachel',
#    'Notley',
#    '.'],
#   'h': ['rachel notley', 'Q7279347', [[25, 26]]],
#   't': ['new democrats', 'Q3345044', [[14, 15]]]},
#  {'tokens': ['The',
#    'seat',
#    'was',
#    'retained',
#    'by',
#    'the',
#    'Conservative',
#    'candidate',
#    'Arthur',
#    'Frederick',
#    'Jeffreys',
#    '.'],
#   'h': ['arthur frederick jeffreys', 'Q4798743', [[8, 9, 10]]],
#   't': ['conservative', 'Q9626', [[6]]]},
#  {'tokens': ['There',
#    'were',
#    'several',
#    'speakers',
#    'including',
#    'Lewis',
#    'Hayden',
#    'who',
#    'had',
#    'brought',
#    'Chappelle',
#    'into',
#    'the',
#    'Republican',
#    'Party',
#    ',',
#    'Hon',
#    '.'],
#   'h': ['lewis hayden', 'Q6536673', [[5, 6]]],
#   't': ['republican party', 'Q29468', [[13, 14]]]},
#  {'tokens': ['The',
#    'current',
#    'Chief',
#    'Minister',
#    'is',
#    'Dato',
#    "'",
#    'Mohamed',
#    'Khaled',
#    'Nordin',
#    'of',
#    'United',
#    'Malays',
#    'National',
#    'Organisation',
#    '.'],
#   'h': ['mohamed khaled nordin', 'Q6891328', [[7, 8, 9]]],
#   't': ['united malays national organisation',
#    'Q1668154',
#    [[11, 12, 13, 14]]]},
#  {'tokens': ['Melton',
#    'shares',
#    'a',
#    'member',
#    'of',
#    'parliament',
#    '(',
#    'currently',
#    'Alan',
#    'Duncan',
#    'from',
#    'the',
#    'Conservatives',
#    ')',
#    'with',
#    'Rutland',
#    ',',
#    'which',
#    'together',
#    'form',
#    'the',
#    'appropriately',
#    'named',
#    '"',
#    'Rutland',
#    'and',
#    'Melton',
#    '"',
#    'parliamentary',
#    'constituency',
#    '.'],
#   'h': ['alan duncan', 'Q302417', [[8, 9]]],
#   't': ['conservatives', 'Q9626', [[12]]]},
#  {'tokens': ['Incumbent',
#    'Democratic',
#    'Governor',
#    'John',
#    'Connally',
#    'was',
#    'reelected',
#    'to',
#    'a',
#    'second',
#    'term',
#    ',',
#    'winning',
#    '74',
#    '%',
#    'of',
#    'the',
#    'vote',
#    'to',
#    'Republican',
#    'Jack',
#    'Crichton',
#    "'s",
#    '26',
#    '%',
#    '.'],
#   'h': ['john connally', 'Q311293', [[3, 4]]],
#   't': ['democratic', 'Q29552', [[1]]]},
#  {'tokens': ['Sir',
#    'Henry',
#    'Kenyon',
#    'Stephenson',
#    ',',
#    '1st',
#    'Baronet',
#    '(',
#    '16',
#    'August',
#    '1865',
#    '–',
#    '20',
#    'September',
#    '1947',
#    ')',
#    'was',
#    'a',
#    'British',
#    'Liberal',
#    'politician',
#    'and',
#    'businessman',
#    '.'],
#   'h': ['henry kenyon stephenson', 'Q7527163', [[1, 2, 3]]],
#   't': ['liberal', 'Q622441', [[19]]]},
#  {'tokens': ['The',
#    'incumbent',
#    'Liberal',
#    'and',
#    'Country',
#    'League',
#    'government',
#    'led',
#    'by',
#    'Premier',
#    'of',
#    'South',
#    'Australia',
#    'Richard',
#    'L.',
#    'Butler',
#    'defeated',
#    'the',
#    'opposition',
#    'Australian',
#    'Labor',
#    'Party',
#    'led',
#    'by',
#    'Leader',
#    'of',
#    'the',
#    'Opposition',
#    'Andrew',
#    'Lacey',
#    '.'],
#   'h': ['andrew lacey', 'Q4757671', [[28, 29]]],
#   't': ['australian labor party', 'Q216082', [[19, 20, 21]]]},
#  {'tokens': ['Anna',
#    'Stiegler',
#    '(',
#    'born',
#    'Anna',
#    'Behrend',
#    ':',
#    '21',
#    'April',
#    '1881',
#    '-',
#    '23',
#    'June',
#    '1963',
#    ')',
#    'was',
#    'a',
#    'German',
#    'politician',
#    '(',
#    'SPD',
#    ')',
#    '.'],
#   'h': ['anna stiegler', 'Q563385', [[0, 1]]],
#   't': ['spd', 'Q49768', [[20]]]},
#  {'tokens': ['Frederick',
#    'Lundin',
#    '(',
#    'May',
#    '18',
#    ',',
#    '1868',
#    '–',
#    'August',
#    '20',
#    ',',
#    '1947',
#    ')',
#    'was',
#    'a',
#    'U.S.',
#    'Representative',
#    'from',
#    'Illinois',
#    'and',
#    'a',
#    'Republican',
#    'Party',
#    'political',
#    'boss',
#    'in',
#    'Chicago',
#    '.'],
#   'h': ['frederick lundin', 'Q5498322', [[0, 1]]],
#   't': ['republican party', 'Q29468', [[21, 22]]]},
#  {'tokens': ['Dewsbury',
#    'is',
#    'a',
#    'constituency',
#    'created',
#    'in',
#    '1868',
#    'represented',
#    'in',
#    'the',
#    'House',
#    'of',
#    'Commons',
#    'of',
#    'the',
#    'UK',
#    'Parliament',
#    'since',
#    '2015',
#    'by',
#    'Paula',
#    'Sherriff',
#    'of',
#    'the',
#    'Labour',
#    'Party',
#    '.'],
#   'h': ['paula sherriff', 'Q20647924', [[20, 21]]],
#   't': ['labour party', 'Q9630', [[24, 25]]]},
#  {'tokens': ['In',
#    'the',
#    '2015',
#    'federal',
#    'election',
#    ',',
#    'McKenna',
#    'defeated',
#    'longtime',
#    'New',
#    'Democratic',
#    'Party',
#    '(',
#    'NDP',
#    ')',
#    'Member',
#    'of',
#    'Parliament',
#    '(',
#    'MP',
#    ')',
#    'Paul',
#    'Dewar',
#    'in',
#    'the',
#    'riding',
#    'of',
#    'Ottawa',
#    'Centre',
#    '.'],
#   'h': ['paul dewar', 'Q3371069', [[21, 22]]],
#   't': ['new democratic party', 'Q130765', [[9, 10, 11]]]},
#  {'tokens': ['In',
#    '1963',
#    ',',
#    'Meyer',
#    'was',
#    'selected',
#    'to',
#    'fight',
#    'the',
#    'constituency',
#    'of',
#    'Eton',
#    'and',
#    'Slough',
#    ',',
#    'then',
#    'held',
#    'by',
#    'Labour',
#    "'s",
#    'leftwing',
#    'internationalist',
#    'Fenner',
#    'Brockway',
#    '.'],
#   'h': ['fenner brockway', 'Q5443535', [[22, 23]]],
#   't': ['labour', 'Q9630', [[18]]]},
#  {'tokens': ['The',
#    'President',
#    'of',
#    'the',
#    'General',
#    'Council',
#    'is',
#    'Jean',
#    '-',
#    'Jacques',
#    'Lozach',
#    'of',
#    'the',
#    'Socialist',
#    'Party',
#    '.'],
#   'h': ['jean-jacques lozach', 'Q3166338', [[7, 8, 9, 10]]],
#   't': ['socialist party', 'Q170972', [[13, 14]]]},
#  {'tokens': ['Sherwood',
#    'is',
#    'a',
#    'constituency',
#    'represented',
#    'in',
#    'the',
#    'House',
#    'of',
#    'Commons',
#    'of',
#    'the',
#    'UK',
#    'Parliament',
#    'since',
#    '2010',
#    'by',
#    'Mark',
#    'Spencer',
#    ',',
#    'a',
#    'Conservative',
#    '.'],
#   'h': ['mark spencer', 'Q389189', [[17, 18]]],
#   't': ['conservative', 'Q9626', [[21]]]},
#  {'tokens': ['First',
#    'Lady',
#    'Jacqueline',
#    'Kennedy',
#    ',',
#    'who',
#    'rarely',
#    'attended',
#    'Democratic',
#    'Party',
#    'events',
#    ',',
#    'spent',
#    'the',
#    'day',
#    'at',
#    'the',
#    'Loudon',
#    'Hunt',
#    'Horse',
#    'Show',
#    'with',
#    'her',
#    'children',
#    ',',
#    'John',
#    '-',
#    'John',
#    'and',
#    'Caroline',
#    '.'],
#   'h': ['john-john', 'Q316064', [[25, 26, 27]]],
#   't': ['democratic party', 'Q29552', [[8, 9]]]},
#  {'tokens': ['All',
#    'India',
#    'Majlis',
#    '-',
#    'e',
#    '-',
#    'Ittehadul',
#    'Muslimeen',
#    '(',
#    'AIMIM',
#    ')',
#    'leader',
#    'Asaduddin',
#    'Owaisi',
#    'addressed',
#    'a',
#    'rally',
#    'in',
#    'Kishanganj',
#    'on',
#    '16',
#    'August',
#    '.'],
#   'h': ['asaduddin owaisi', 'Q3210225', [[12, 13]]],
#   't': ['all india majlis-e-ittehadul muslimeen',
#    'Q2837501',
#    [[0, 1, 2, 3, 4, 5, 6, 7]]]},
#  {'tokens': ['She',
#    'has',
#    'been',
#    'the',
#    'communication',
#    'director',
#    'for',
#    'Republican',
#    'former',
#    'U.S.',
#    'Representative',
#    'Joseph',
#    'Cao',
#    'of',
#    'New',
#    'Orleans',
#    ',',
#    'Louisiana',
#    ',',
#    'and',
#    'an',
#    'intern',
#    'for',
#    'former',
#    'Arkansas',
#    'governor',
#    'and',
#    'presidential',
#    'candidate',
#    'Mike',
#    'Huckabee',
#    '.'],
#   'h': ['joseph cao', 'Q336324', [[11, 12]]],
#   't': ['republican', 'Q29468', [[7]]]},
#  {'tokens': ['In',
#    '1978',
#    ',',
#    'he',
#    'was',
#    'the',
#    'GOP',
#    'nominee',
#    'for',
#    'governor',
#    ',',
#    'but',
#    'was',
#    'defeated',
#    'by',
#    'the',
#    'Democratic',
#    'incumbent',
#    ',',
#    'John',
#    'Evans',
#    'of',
#    'Malad',
#    '.'],
#   'h': ['john evans', 'Q328527', [[19, 20]]],
#   't': ['democratic', 'Q29552', [[16]]]},
#  {'tokens': ['He',
#    'then',
#    'supported',
#    'Tariana',
#    'Turia',
#    'when',
#    'she',
#    'quit',
#    'the',
#    'Labour',
#    'Party',
#    'and',
#    'founded',
#    'the',
#    'new',
#    'Māori',
#    'Party',
#    'where',
#    'Jackson',
#    'and',
#    'McCarten',
#    'played',
#    'supporting',
#    'roles',
#    '.'],
#   'h': ['tariana turia', 'Q466117', [[3, 4]]],
#   't': ['labour party', 'Q1048192', [[9, 10]]]},
#  {'tokens': ['"',
#    'Piratpartiet',
#    'får',
#    'två',
#    'mandat',
#    'i',
#    'ny',
#    'mätning',
#    '"',
#    'from',
#    'dn.se',
#    '(',
#    'Swedish',
#    ')',
#    ',',
#    '"',
#    'accessed',
#    'on',
#    'May',
#    '30',
#    ',',
#    '2009',
#    '"',
#    'The',
#    'party',
#    "'s",
#    'top',
#    'two',
#    'candidates',
#    'are',
#    'Christian',
#    'Engström',
#    'and',
#    'Amelia',
#    'Andersdotter',
#    '.'],
#   'h': ['amelia andersdotter', 'Q235374', [[33, 34]]],
#   't': ['piratpartiet', 'Q208602', [[1]]]},
#  {'tokens': ['He',
#    'soon',
#    'assumed',
#    'the',
#    'role',
#    'of',
#    'Floor',
#    'leader',
#    'for',
#    'the',
#    'Democrats',
#    'during',
#    'the',
#    'governorship',
#    'of',
#    'Ray',
#    'Blanton',
#    'and',
#    'later',
#    'became',
#    'House',
#    'Majority',
#    'Leader',
#    'during',
#    'the',
#    'governorships',
#    'of',
#    'Lamar',
#    'Alexander',
#    'and',
#    'Ned',
#    'McWherter',
#    '.'],
#   'h': ['ray blanton', 'Q885000', [[15, 16]]],
#   't': ['democrats', 'Q29552', [[10]]]},
#  {'tokens': ['Charles',
#    'Kinney',
#    '(',
#    'July',
#    '7',
#    ',',
#    '1850',
#    '–',
#    'September',
#    '15',
#    ',',
#    '1918',
#    ')',
#    'was',
#    'a',
#    'Republican',
#    'politician',
#    'who',
#    'was',
#    'Ohio',
#    'Secretary',
#    'of',
#    'State',
#    'from',
#    '1897',
#    'to',
#    '1901',
#    '.'],
#   'h': ['charles kinney', 'Q5079817', [[0, 1]]],
#   't': ['republican', 'Q29468', [[15]]]},
#  {'tokens': ['Appointed',
#    'by',
#    'Republican',
#    'Governor',
#    'Mary',
#    'Fallin',
#    'as',
#    'Oklahoma',
#    'Secretary',
#    'of',
#    'Agriculture',
#    ',',
#    'Reese',
#    'was',
#    'sworn',
#    'into',
#    'office',
#    'on',
#    'January',
#    '10',
#    ',',
#    '2011',
#    '.'],
#   'h': ['mary fallin', 'Q257237', [[4, 5]]],
#   't': ['republican', 'Q29468', [[2]]]},
#  {'tokens': ['The',
#    'status',
#    'would',
#    'be',
#    'short',
#    'lived',
#    'as',
#    'Republican',
#    'Michael',
#    'Grimm',
#    'would',
#    'defeat',
#    'McMahon',
#    '2',
#    'years',
#    'later',
#    '.'],
#   'h': ['michael grimm', 'Q32726', [[8, 9]]],
#   't': ['republican', 'Q29468', [[7]]]},
#  {'tokens': ['A',
#    'Democrat',
#    ',',
#    'in',
#    'the',
#    '1990s',
#    ',',
#    'he',
#    'staged',
#    'two',
#    'unsuccessful',
#    'U.S.',
#    'Senatorial',
#    'campaigns',
#    'against',
#    'Republican',
#    'Jesse',
#    'Helms',
#    'in',
#    '1990',
#    'and',
#    'in',
#    '1996',
#    ',',
#    'gaining',
#    '47',
#    '%',
#    'and',
#    '46',
#    '%',
#    'of',
#    'the',
#    'vote',
#    ',',
#    'respectively',
#    '.'],
#   'h': ['jesse helms', 'Q503426', [[16, 17]]],
#   't': ['republican', 'Q29468', [[15]]]},
#  {'tokens': ['Barker',
#    'was',
#    'at',
#    'first',
#    'unsuccessful',
#    'in',
#    'his',
#    'attempts',
#    'to',
#    'be',
#    'elected',
#    'to',
#    'Parliament',
#    'when',
#    'he',
#    'contested',
#    'the',
#    'safe',
#    'Labour',
#    'seat',
#    'of',
#    'Eccles',
#    ',',
#    'where',
#    'he',
#    'was',
#    'defeated',
#    'by',
#    'Ian',
#    'Stewart',
#    '.'],
#   'h': ['ian stewart', 'Q5982982', [[28, 29]]],
#   't': ['labour', 'Q9630', [[18]]]},
#  {'tokens': ['He',
#    'was',
#    're',
#    '-',
#    'elected',
#    'in',
#    '1922',
#    ',',
#    '\n',
#    'but',
#    'at',
#    'the',
#    '1923',
#    'election',
#    'he',
#    'was',
#    'defeated',
#    'by',
#    'the',
#    'Liberal',
#    'Party',
#    'candidate',
#    'Eric',
#    'Macfadyen',
#    '.'],
#   'h': ['eric macfadyen', 'Q5387018', [[22, 23]]],
#   't': ['liberal party', 'Q622441', [[19, 20]]]},
#  {'tokens': ['Henrik',
#    'von',
#    'Sydow',
#    '(',
#    'born',
#    '1976',
#    ')',
#    'is',
#    'a',
#    'Swedish',
#    'politician',
#    'of',
#    'the',
#    'Moderate',
#    'Party',
#    ',',
#    'member',
#    'of',
#    'the',
#    'Riksdag',
#    'from',
#    '2002',
#    'to',
#    '2014',
#    '.'],
#   'h': ['henrik von sydow', 'Q5716610', [[0, 1, 2]]],
#   't': ['moderate party', 'Q110843', [[13, 14]]]},
#  {'tokens': ['Duncan',
#    "'s",
#    'first',
#    'full',
#    '-',
#    'time',
#    'job',
#    'after',
#    'graduating',
#    'from',
#    'university',
#    'was',
#    'in',
#    'the',
#    'office',
#    'of',
#    'federal',
#    'Liberal',
#    'Member',
#    'of',
#    'Parliament',
#    '(',
#    'MP',
#    ')',
#    'Herb',
#    'Gray',
#    '.'],
#   'h': ['herb gray', 'Q1548798', [[24, 25]]],
#   't': ['liberal', 'Q138345', [[17]]]},
#  {'tokens': ['Guillermina',
#    'López',
#    'Balbuena',
#    '(',
#    'born',
#    '25',
#    'June',
#    '1973',
#    ')',
#    'is',
#    'a',
#    'Mexican',
#    'politician',
#    'from',
#    'the',
#    'Institutional',
#    'Revolutionary',
#    'Party',
#    '.'],
#   'h': ['guillermina lópez balbuena', 'Q19519049', [[0, 1, 2]]],
#   't': ['institutional revolutionary party', 'Q682969', [[15, 16, 17]]]},
#  {'tokens': ['Thomas',
#    'Watkins',
#    'Ligon',
#    '(',
#    'May',
#    '10',
#    ',',
#    '1810January',
#    '12',
#    ',',
#    '1881',
#    ')',
#    ',',
#    'a',
#    'Democrat',
#    ',',
#    'was',
#    'the',
#    '30th',
#    'Governor',
#    'of',
#    'Maryland',
#    'in',
#    'the',
#    'United',
#    'States',
#    'from',
#    '1854',
#    'to',
#    '1858',
#    '.'],
#   'h': ['thomas watkins ligon', 'Q683620', [[0, 1, 2]]],
#   't': ['democrat', 'Q29552', [[14]]]},
#  {'tokens': ['He',
#    'supported',
#    'Champ',
#    'Clark',
#    'for',
#    'the',
#    'Democratic',
#    'presidential',
#    'nomination',
#    'in',
#    '1912',
#    ',',
#    'but',
#    'after',
#    'Clark',
#    "'s",
#    'defeat',
#    'he',
#    'worked',
#    'for',
#    'the',
#    'Woodrow',
#    'Wilson',
#    'campaign',
#    'in',
#    '1912',
#    'and',
#    '1916',
#    '.'],
# ...
#    'March',
#    '1962',
#    ')',
#    'is',
#    'a',
#    'Norwegian',
#    'politician',
#    'for',
#    'the',
#    'Centre',
#    'Party',
#    '.'],
#   'h': ['jenny ellaug følling', 'Q11978380', [[0, 1, 2]]],
#   't': ['centre party', 'Q493685', [[15, 16]]]},
#  {'tokens': ['Wolfgang',
#    'Schäuble',
#    '(',
#    'born',
#    '18',
#    'September',
#    '1942',
#    ')',
#    'is',
#    'a',
#    'German',
#    'lawyer',
#    'and',
#    'politician',
#    'of',
#    'the',
#    'Christian',
#    'Democratic',
#    'Union',
#    '(',
#    'CDU',
#    ')',
#    'whose',
#    'political',
#    'career',
#    'has',
#    'spanned',
#    'more',
#    'than',
#    'four',
#    'decades',
#    '.'],
#   'h': ['wolfgang schäuble', 'Q16019', [[0, 1]]],
#   't': ['christian democratic union', 'Q49762', [[16, 17, 18]]]},
#  {'tokens': ['During',
#    'the',
#    'night',
#    ',',
#    'Israeli',
#    'warplanes',
#    'bombed',
#    'the',
#    'house',
#    'of',
#    'senior',
#    'Hamas',
#    'leader',
#    'Mahmoud',
#    'al',
#    '-',
#    'Zahar',
#    '.'],
#   'h': ['mahmoud al-zahar', 'Q708854', [[13, 14, 15, 16]]],
#   't': ['hamas', 'Q38799', [[11]]]},
#  {'tokens': ['This',
#    'new',
#    'strand',
#    'of',
#    'thinking',
#    'in',
#    'Fine',
#    'Gael',
#    'paved',
#    'the',
#    'way',
#    'for',
#    'the',
#    'rise',
#    'within',
#    'the',
#    'party',
#    'of',
#    'liberal',
#    'thinkers',
#    'such',
#    'as',
#    'Garret',
#    'FitzGerald',
#    '.'],
#   'h': ['garret fitzgerald', 'Q1425313', [[22, 23]]],
#   't': ['fine gael', 'Q247135', [[6, 7]]]},
#  {'tokens': ['She',
#    'was',
#    'elected',
#    'to',
#    'her',
#    'seat',
#    'in',
#    '2016',
#    ',',
#    'unseating',
#    'Republican',
#    'incumbent',
#    'JoAnn',
#    'Windholz',
#    '.'],
#   'h': ['joann windholz', 'Q22058752', [[12, 13]]],
#   't': ['republican', 'Q29468', [[10]]]},
#  {'tokens': ['Churwell',
#    'is',
#    'in',
#    'the',
#    'new',
#    'Morley',
#    'and',
#    'Outwood',
#    'constituency',
#    ',',
#    'and',
#    'is',
#    'represented',
#    'by',
#    'Andrea',
#    'Jenkyns',
#    '(',
#    'Conservative',
#    ')',
#    '.'],
#   'h': ['andrea jenkyns', 'Q19874642', [[14, 15]]],
#   't': ['conservative', 'Q9626', [[17]]]},
#  {'tokens': ['Chesterfield',
#    'is',
#    'a',
#    'constituency',
#    'represented',
#    'in',
#    'the',
#    'House',
#    'of',
#    'Commons',
#    'of',
#    'the',
#    'UK',
#    'Parliament',
#    'since',
#    'the',
#    '2010',
#    'general',
#    'election',
#    'by',
#    'Toby',
#    'Perkins',
#    'of',
#    'the',
#    'Labour',
#    'Party',
#    '.'],
#   'h': ['toby perkins', 'Q575462', [[20, 21]]],
#   't': ['labour party', 'Q9630', [[24, 25]]]},
#  {'tokens': ['The',
#    'former',
#    'Venstre',
#    'leader',
#    'and',
#    'former',
#    'Prime',
#    'Minister',
#    'Knud',
#    'Kristensen',
#    'had',
#    'broken',
#    'away',
#    'from',
#    'Venstre',
#    'to',
#    'form',
#    'his',
#    'own',
#    'party',
#    ',',
#    '"',
#    'De',
#    'Uafhængige',
#    '"',
#    '.'],
#   'h': ['knud kristensen', 'Q1335084', [[8, 9]]],
#   't': ['venstre', 'Q217321', [[2], [14]]]},
#  {'tokens': ['At',
#    'the',
#    'by',
#    '-',
#    'election',
#    ',',
#    'he',
#    'defeated',
#    'Rod',
#    'Kenyon',
#    'and',
#    'Jacqui',
#    'Lait',
#    ',',
#    'later',
#    'the',
#    'Conservative',
#    'Member',
#    'of',
#    'Parliament',
#    'for',
#    'Beckenham',
#    '.'],
#   'h': ['jacqui lait', 'Q6121041', [[11, 12]]],
#   't': ['conservative', 'Q9626', [[16]]]},
#  {'tokens': ['Wojciech',
#    'Wierzejski',
#    'was',
#    'a',
#    'Member',
#    'of',
#    'the',
#    'European',
#    'Parliament',
#    ',',
#    'and',
#    'then',
#    'a',
#    'Deputy',
#    'of',
#    'the',
#    'Sejm',
#    'from',
#    'the',
#    'League',
#    'of',
#    'Polish',
#    'Families',
#    '.'],
#   'h': ['wojciech wierzejski', 'Q714082', [[0, 1]]],
#   't': ['league of polish families', 'Q687574', [[19, 20, 21, 22]]]},
#  {'tokens': ['The',
#    'group',
#    'has',
#    'seventeen',
#    'members',
#    ',',
#    'including',
#    'former',
#    'UKIP',
#    'MEP',
#    'Tim',
#    'Aker',
#    ',',
#    'and',
#    'forms',
#    'the',
#    'opposition',
#    'group',
#    'on',
#    'Thurrock',
#    'Council',
#    '.'],
#   'h': ['tim aker', 'Q16751995', [[10, 11]]],
#   't': ['ukip', 'Q10647', [[8]]]},
#  {'tokens': ['When',
#    'Bondfield',
#    'tabled',
#    'the',
#    'WLL',
#    'motion',
#    'at',
#    'the',
#    'Labour',
#    'conference',
#    ',',
#    'she',
#    'was',
#    'persuaded',
#    'by',
#    'Arthur',
#    'Henderson',
#    'to',
#    'water',
#    'it',
#    'down',
#    '.'],
#   'h': ['arthur henderson', 'Q208665', [[15, 16]]],
#   't': ['labour', 'Q9630', [[8]]]},
#  {'tokens': ['In',
#    '2011',
#    'He',
#    'was',
#    'elected',
#    'to',
#    'serve',
#    'the',
#    'Falkirk',
#    'East',
#    'constituency',
#    ',',
#    'gaining',
#    'over',
#    '50',
#    '%',
#    'of',
#    'the',
#    'vote',
#    ',',
#    'ousting',
#    'Labour',
#    "'s",
#    'Cathy',
#    'Peattie',
#    'who',
#    'had',
#    'been',
#    'the',
#    'MSP',
#    'since',
#    '1999',
#    '.'],
#   'h': ['cathy peattie', 'Q1051152', [[23, 24]]],
#   't': ['labour', 'Q9630', [[21]]]},
#  {'tokens': ['Fuller',
#    'stood',
#    'as',
#    'the',
#    'Conservative',
#    'candidate',
#    'for',
#    'the',
#    'Bedford',
#    'constituency',
#    'in',
#    'the',
#    '2005',
#    'general',
#    'election',
#    ',',
#    'losing',
#    'to',
#    'the',
#    'incumbent',
#    'Labour',
#    'MP',
#    'Patrick',
#    'Hall',
#    '.'],
#   'h': ['patrick hall', 'Q7146637', [[22, 23]]],
#   't': ['labour', 'Q9630', [[20]]]},
#  {'tokens': ['In',
#    'a',
#    'similar',
#    'accusation',
#    ',',
#    'the',
#    'former',
#    'BJP',
#    'Chief',
#    'Minister',
#    ',',
#    'Prem',
#    'Kumar',
#    'Dhumal',
#    ',',
#    'had',
#    'rejected',
#    'those',
#    'charges',
#    ',',
#    'defending',
#    'the',
#    'grant',
#    'of',
#    'relaxations',
#    'to',
#    'the',
#    'educational',
#    'trust',
#    '.'],
#   'h': ['prem kumar dhumal', 'Q3520354', [[11, 12, 13]]],
#   't': ['bjp', 'Q10230', [[7]]]},
#  {'tokens': ['Griffin',
#    're',
#    '-',
#    'entered',
#    'politics',
#    'in',
#    '1993',
#    'and',
#    ',',
#    'in',
#    '1995',
#    ',',
#    'at',
#    'the',
#    'behest',
#    'of',
#    'John',
#    'Tyndall',
#    ',',
#    'joined',
#    'the',
#    'British',
#    'National',
#    'Party',
#    '(',
#    'BNP',
#    ')',
#    '.'],
#   'h': ['john tyndall', 'Q2749419', [[16, 17]]],
#   't': ['british national party', 'Q161269', [[21, 22, 23]]]},
#  {'tokens': ['Other',
#    'potential',
#    'Democratic',
#    'candidates',
#    'include',
#    'former',
#    'Lieutenant',
#    'Governor',
#    'Joseph',
#    'García',
#    ',',
#    'and',
#    'former',
#    'State',
#    'House',
#    'Speaker',
#    'Mark',
#    'Ferrandino',
#    '.'],
#   'h': ['joseph garcía', 'Q6283356', [[8, 9]]],
#   't': ['democratic', 'Q29552', [[2]]]},
#  {'tokens': ['He',
#    'faced',
#    'former',
#    'State',
#    'Representative',
#    'Kenneth',
#    'A.',
#    'Gottlieb',
#    'and',
#    'Broward',
#    'County',
#    'School',
#    'Board',
#    'Member',
#    'Eleanor',
#    'Sobel',
#    'in',
#    'the',
#    'Democratic',
#    'primary',
#    '.'],
#   'h': ['eleanor sobel', 'Q5354391', [[14, 15]]],
#   't': ['democratic', 'Q29552', [[18]]]},
#  {'tokens': ['Martin',
#    'Holmes',
#    "'",
#    'publication',
#    'of',
#    '"',
#    'The',
#    'Conservative',
#    'Party',
#    'and',
#    'Europe',
#    '"',
#    'had',
#    'a',
#    'strong',
#    'influence',
#    'on',
#    'William',
#    'Hague',
#    '.'],
#   'h': ['william hague', 'Q58282', [[17, 18]]],
#   't': ['conservative party', 'Q9626', [[7, 8]]]},
#  {'tokens': ['His',
#    'cousin',
#    'Juan',
#    'Dalmau',
#    ',',
#    'is',
#    'one',
#    'of',
#    'the',
#    'leaders',
#    'of',
#    'the',
#    'Puerto',
#    'Rican',
#    'Independence',
#    'Party',
#    '(',
#    'PIP',
#    ')',
#    'and',
#    'their',
#    'candidate',
#    'for',
#    'Governor',
#    'in',
#    '2008',
#    ',',
#    'and',
#    'subsequently',
#    'a',
#    'Senator',
#    'At',
#    '-',
#    'Large',
#    '.'],
#   'h': ['juan dalmau', 'Q6299578', [[2, 3]]],
#   't': ['puerto rican independence party', 'Q19683', [[12, 13, 14, 15]]]},
#  {'tokens': ['William',
#    'Irvin',
#    'Swoope',
#    '(',
#    'October',
#    '3',
#    ',',
#    '1862',
#    '–',
#    'October',
#    '9',
#    ',',
#    '1930',
#    ')',
#    'was',
#    'a',
#    'Republican',
#    'member',
#    'of',
#    'the',
#    'U.S.',
#    'House',
#    'of',
#    'Representatives',
#    'from',
#    'Pennsylvania',
#    '.'],
#   'h': ['william irvin swoope', 'Q13219840', [[0, 1, 2]]],
#   't': ['republican', 'Q29468', [[16]]]},
#  {'tokens': ['Political',
#    'activist',
#    'Tom',
#    'Hoefling',
#    'unsuccessfully',
#    'challenged',
#    'Branstad',
#    'for',
#    'the',
#    'Republican',
#    'nomination',
#    '.'],
#   'h': ['tom hoefling', 'Q7816212', [[2, 3]]],
#   't': ['republican', 'Q29468', [[9]]]},
#  {'tokens': ['Stefanos',
#    'Manikas',
#    '(',
#    '14',
#    'April',
#    '1952',
#    '–',
#    '26',
#    'August',
#    '2015',
#    ')',
#    'was',
#    'a',
#    'Greek',
#    'politician',
#    'of',
#    'the',
#    'Panhellenic',
#    'Socialist',
#    'Movement',
#    '(',
#    'PASOK',
#    ')',
#    'who',
#    'was',
#    'Minister',
#    'of',
#    'State',
#    '.'],
#   'h': ['stefanos manikas', 'Q19800985', [[0, 1]]],
#   't': ['pasok', 'Q203934', [[21]]]},
#  {'tokens': ['The',
#    'ALP',
#    'lost',
#    'the',
#    '2004',
#    'general',
#    'election',
#    'and',
#    'were',
#    'replaced',
#    'by',
#    'a',
#    'United',
#    'Progressive',
#    'Party',
#    'government',
#    'under',
#    'Baldwin',
#    'Spencer',
#    '.'],
#   'h': ['baldwin spencer', 'Q57602', [[17, 18]]],
#   't': ['united progressive party', 'Q1285399', [[12, 13, 14]]]},
#  {'tokens': ['Together',
#    'with',
#    'them',
#    'and',
#    'fellow',
#    'MEPs',
#    'Michał',
#    'Kamiński',
#    ',',
#    'Adam',
#    'Bielan',
#    ',',
#    'and',
#    'Paweł',
#    'Kowal',
#    ',',
#    'Migalski',
#    'formed',
#    'the',
#    'more',
#    'centrist',
#    'Poland',
#    'Comes',
#    'First',
#    ',',
#    'which',
#    'was',
#    'joined',
#    'by',
#    'a',
#    'total',
#    'of',
#    '17',
#    'MPs',
#    '.'],
#   'h': ['adam bielan', 'Q2507571', [[9, 10]]],
#   't': ['poland comes first', 'Q1784503', [[21, 22, 23]]]},
#  {'tokens': ['He',
#    'was',
#    'defeated',
#    'at',
#    'the',
#    '1906',
#    'general',
#    'election',
#    'by',
#    'William',
#    'Dudley',
#    'Ward',
#    'and',
#    'Sir',
#    'Ivor',
#    'Philipps',
#    'of',
#    'the',
#    'Liberal',
#    'Party',
#    '.'],
#   'h': ['ivor philipps', 'Q6099477', [[14, 15]]],
#   't': ['liberal party', 'Q622441', [[18, 19]]]},
#  {'tokens': ['Democratic',
#    'Party',
#    "'s",
#    'Kam',
#    'Nai',
#    '-',
#    'wai',
#    'was',
#    'able',
#    'to',
#    'take',
#    'the',
#    'chairmanship',
#    'with',
#    'the',
#    'help',
#    'of',
#    'appointed',
#    'member',
#    'Wu',
#    'Chor',
#    '-',
#    'nam',
#    '.'],
#   'h': ['kam nai-wai', 'Q3051937', [[3, 4, 5, 6]]],
#   't': ['democratic party', 'Q21892', [[0, 1]]]},
#  {'tokens': ['He',
#    'became',
#    'deputy',
#    'leader',
#    'of',
#    'the',
#    'Scottish',
#    'Conservatives',
#    'in',
#    'November',
#    '2005',
#    'when',
#    'Annabel',
#    'Goldie',
#    'became',
#    'leader',
#    '.'],
#   'h': ['annabel goldie', 'Q544742', [[12, 13]]],
#   't': ['scottish conservatives', 'Q3243587', [[6, 7]]]},
#  {'tokens': ['Republican',
#    'Melissa',
#    'Murray',
#    'Bailey',
#    ',',
#    'a',
#    'business',
#    'executive',
#    ',',
#    'ran',
#    'unopposed',
#    'for',
#    'the',
#    'Republican',
#    'nomination',
#    '.'],
#   'h': ['melissa murray bailey', 'Q21964316', [[1, 2, 3]]],
#   't': ['republican', 'Q29468', [[0], [13]]]},
#  {'tokens': ['Erik',
#    'Marais',
#    'is',
#    'a',
#    'South',
#    'African',
#    'politician',
#    ',',
#    'currently',
#    'a',
#    'Member',
#    'of',
#    'Parliament',
#    'with',
#    'the',
#    'Democratic',
#    'Alliance',
#    ',',
#    'and',
#    'the',
#    'Shadow',
#    'Deputy',
#    'Minister',
#    'of',
#    'Public',
#    'Enterprises',
#    '.'],
#   'h': ['erik marais', 'Q5388710', [[0, 1]]],
#   't': ['democratic alliance', 'Q761877', [[15, 16]]]},
#  {'tokens': ['Their',
#    'main',
#    'opponent',
#    ',',
#    'Frank',
#    '-',
#    'Walter',
#    'Steinmeier',
#    "'s",
#    'Social',
#    'Democratic',
#    'Party',
#    '(',
#    'SPD',
#    ')',
#    ',',
#    'conceded',
#    'defeat',
#    '.'],
#   'h': ['frank-walter steinmeier', 'Q76658', [[4, 5, 6, 7]]],
#   't': ['spd', 'Q49768', [[13]]]},
#  {'tokens': ['The',
#    'current',
#    'Deputy',
#    'Prime',
#    'Minister',
#    'is',
#    'Yannis',
#    'Dragasakis',
#    ',',
#    'member',
#    'of',
#    'the',
#    'Coalition',
#    'of',
#    'the',
#    'Radical',
#    'Left',
#    '(',
#    'SYRIZA',
#    ')',
#    'in',
#    'the',
#    'coalition',
#    'cabinet',
#    'of',
#    'Alexis',
#    'Tsipras',
#    '(',
#    'SYRIZA',
#    '–',
#    'ANEL',
#    'coalition',
#    ')',
#    '.'],
#   'h': ['yannis dragasakis', 'Q5558236', [[6, 7]]],
#   't': ['coalition of the radical left', 'Q222897', [[12, 13, 14, 15, 16]]]},
#  {'tokens': ['In',
#    'November',
#    '2006',
#    ',',
#    'he',
#    'applied',
#    'for',
#    'selection',
#    'as',
#    'the',
#    'Conservative',
#    'parliamentary',
#    'candidate',
#    'for',
#    'Witham',
#    'in',
#    'Essex',
#    ',',
#    'but',
#    'he',
#    'was',
#    'defeated',
#    'by',
#    'Priti',
#    'Patel',
#    '.'],
#   'h': ['priti patel', 'Q575733', [[23, 24]]],
#   't': ['conservative', 'Q9626', [[10]]]},
#  {'tokens': ['In',
#    '2014',
#    'the',
#    'SWAPO',
#    'presidential',
#    'candidate',
#    'was',
#    'Hage',
#    'Geingob',
#    'who',
#    'was',
#    'the',
#    'Vice',
#    '-',
#    'President',
#    'of',
#    'SWAPO',
#    '.'],
#   'h': ['hage geingob', 'Q1568274', [[7, 8]]],
#   't': ['swapo', 'Q467711', [[3], [16]]]},
#  {'tokens': ['He',
#    'unsuccessfully',
#    'contested',
#    'Hastings',
#    'at',
#    'both',
#    'the',
#    'February',
#    'and',
#    'October',
#    '1974',
#    'general',
#    'elections',
#    'and',
#    'again',
#    'at',
#    'the',
#    '1979',
#    'General',
#    'Election',
#    ',',
#    'and',
#    'on',
#    'each',
#    'occasion',
#    'was',
#    'defeated',
#    'by',
#    'the',
#    'sitting',
#    'Conservative',
#    'MP',
#    'Kenneth',
#    'Warren',
#    '.'],
#   'h': ['kenneth warren', 'Q6390813', [[32, 33]]],
#   't': ['conservative', 'Q9626', [[30]]]},
#  {'tokens': ['North',
#    'Herefordshire',
#    'is',
#    'a',
#    'constituency',
#    'represented',
#    'in',
#    'the',
#    'House',
#    'of',
#    'Commons',
#    'of',
#    'the',
#    'UK',
#    'Parliament',
#    'since',
#    'its',
#    '2010',
#    'creation',
#    'by',
#    'Bill',
#    'Wiggin',
#    ',',
#    'a',
#    'Conservative',
#    '.'],
#   'h': ['bill wiggin', 'Q265900', [[20, 21]]],
#   't': ['conservative', 'Q9626', [[24]]]},
#  {'tokens': ['Nils',
#    'Oskar',
#    'Nilsson',
#    '(',
#    'born',
#    '1935',
#    ')',
#    'is',
#    'a',
#    'Swedish',
#    'politician',
#    'of',
#    'the',
#    'Moderate',
#    'Party',
#    '.'],
#   'h': ['nils oskar nilsson', 'Q6011391', [[0, 1, 2]]],
#   't': ['moderate party', 'Q110843', [[13, 14]]]},
#  {'tokens': ['He',
#    'fought',
#    'Cardiff',
#    'South',
#    'East',
#    'in',
#    '1955',
#    'and',
#    '1959',
#    ',',
#    'being',
#    'defeated',
#    'both',
#    'times',
#    'by',
#    'future',
#    'Labour',
#    'Prime',
#    'Minister',
#    'James',
#    'Callaghan',
#    ',',
#    'on',
#    'the',
#    'second',
#    'occasion',
#    'by',
#    'only',
#    '868',
#    'votes',
#    '.'],
#   'h': ['james callaghan', 'Q9576', [[19, 20]]],
#   't': ['labour', 'Q9630', [[16]]]},
#  {'tokens': ['The',
#    'program',
#    'sees',
#    'two',
#    'former',
#    'Labor',
#    'Party',
#    'politicians',
#    'Kristina',
#    'Keneally',
#    'and',
#    'Craig',
#    'Emerson',
#    'discuss',
#    'political',
#    'issues',
#    'of',
#    'the',
#    'week',
#    'with',
#    'two',
#    'former',
#    'Liberal',
#    'Party',
#    'politicians',
#    'Peter',
#    'Reith',
#    'and',
#    'Helen',
#    'Coonan',
#    '.'],
#   'h': ['craig emerson', 'Q5180933', [[11, 12]]],
#   't': ['labor party', 'Q216082', [[5, 6]]]},
#  {'tokens': ['Weaver',
#    'and',
#    'Field',
#    'defeated',
#    'the',
#    'Republican',
#    'nominees',
#    ',',
#    'incumbent',
#    'President',
#    'Benjamin',
#    'Harrison',
#    'of',
#    'Indiana',
#    'and',
#    'his',
#    'running',
#    'mate',
#    'Whitelaw',
#    'Reid',
#    'of',
#    'Ohio',
#    '.'],
#   'h': ['whitelaw reid', 'Q1386012', [[18, 19]]],
#   't': ['republican', 'Q29468', [[5]]]},
#  {'tokens': ['William',
#    'Alfred',
#    'Robinson',
#    '(',
#    '12',
#    'July',
#    '1905',
#    '–',
#    '15',
#    'November',
#    '1957',
#    ')',
#    'was',
#    'a',
#    'Liberal',
#    'party',
#    'member',
#    'of',
#    'the',
#    'Canadian',
#    'House',
#    'of',
#    'Commons',
#    '.'],
#   'h': ['william alfred robinson', 'Q8004312', [[0, 1, 2]]],
#   't': ['liberal party', 'Q138345', [[14, 15]]]}]

# %%
data['P106']
# Out:
# [{'tokens': ['Cunlhat',
#    'was',
#    'the',
#    'birthplace',
#    'of',
#    'Maurice',
#    'Pialat',
#    '(',
#    '1925–2003',
#    ')',
#    ',',
#    'film',
#    'director',
#    'and',
#    'actor',
#    '.'],
#   'h': ['maurice pialat', 'Q503898', [[5, 6]]],
#   't': ['film director', 'Q2526255', [[11, 12]]]},
#  {'tokens': ['Use',
#    'of',
#    'the',
#    'Seneca',
#    'College',
#    'computing',
#    'infrastructure',
#    ',',
#    'which',
#    'was',
#    'loaned',
#    'for',
#    'free',
#    'for',
#    'the',
#    'production',
#    ',',
#    'was',
#    'valued',
#    'by',
#    'NFB',
#    'producer',
#    'Marcy',
#    'Page',
#    'at',
#    'about',
#    '.'],
#   'h': ['marcy page', 'Q19748197', [[22, 23]]],
#   't': ['producer', 'Q3282637', [[21]]]},
#  {'tokens': ['When',
#    'McClaren',
#    'was',
#    'appointed',
#    'as',
#    'England',
#    'manager',
#    'in',
#    'the',
#    'summer',
#    'of',
#    '2006',
#    ',',
#    'new',
#    'Middlesbrough',
#    'manager',
#    'Gareth',
#    'Southgate',
#    'appointed',
#    'Crosby',
#    'as',
#    'assistant',
#    'manager',
#    '.'],
#   'h': ['gareth southgate', 'Q316681', [[16, 17]]],
#   't': ['manager', 'Q628099', [[6], [15], [22]]]},
#  {'tokens': ['Mordechai',
#    'Willig',
#    '(',
#    'born',
#    'April',
#    '25',
#    ',',
#    '1947',
#    ')',
#    'is',
#    'an',
#    'Orthodox',
#    'rabbi',
#    'and',
#    'rosh',
#    'yeshiva',
#    'at',
#    'Yeshiva',
#    'University',
#    'in',
#    'Washington',
#    'Heights',
#    ',',
#    'Manhattan',
#    '.'],
#   'h': ['mordechai willig', 'Q6909685', [[0, 1]]],
#   't': ['rabbi', 'Q133485', [[12]]]},
#  {'tokens': ['He',
#    'served',
#    'as',
#    'an',
#    'assistant',
#    '/',
#    'associate',
#    'head',
#    'coach',
#    'under',
#    'Nolan',
#    'Richardson',
#    'at',
#    'Arkansas',
#    'for',
#    '17',
#    'years',
#    '.'],
#   'h': ['nolan richardson', 'Q3342871', [[10, 11]]],
#   't': ['coach', 'Q5137571', [[8]]]},
#  {'tokens': ['Bob',
#    'Sheridan',
#    '(',
#    'born',
#    '1944',
#    'in',
#    'Boston',
#    ')',
#    'is',
#    'an',
#    'American',
#    'boxing',
#    'and',
#    'MMA',
#    'commentator',
#    '.'],
#   'h': ['bob sheridan', 'Q4933964', [[0, 1]]],
#   't': ['commentator', 'Q2986228', [[14]]]},
#  {'tokens': ['George',
#    'Chapman',
#    '(',
#    '?',
#    '1559-?1634',
#    ')',
#    'was',
#    'a',
#    'successful',
#    'playwright',
#    'who',
#    'is',
#    'remembered',
#    'chiefly',
#    'for',
#    'his',
#    'translation',
#    'in',
#    '1616',
#    'of',
#    'Homer',
#    "'s",
#    'Iliad',
#    'and',
#    'Odyssey',
#    'into',
#    'English',
#    'verse',
#    '.'],
#   'h': ['george chapman', 'Q342720', [[0, 1]]],
#   't': ['playwright', 'Q214917', [[9]]]},
#  {'tokens': ['Henry',
#    'considered',
#    'retiring',
#    'from',
#    'international',
#    'football',
#    'due',
#    'to',
#    'the',
#    'reactions',
#    'to',
#    'the',
#    'game',
#    ',',
#    'while',
#    'the',
#    'Swedish',
#    'match',
#    'referee',
#    'Martin',
#    'Hansson',
#    'considered',
#    'quitting',
#    'as',
#    'a',
#    'referee',
#    '.'],
#   'h': ['martin hansson', 'Q311551', [[19, 20]]],
#   't': ['match referee', 'Q859528', [[17, 18]]]},
#  {'tokens': ['Charles',
#    'Richmond',
#    'Henderson',
#    '(',
#    '1848–1915',
#    ')',
#    'was',
#    'an',
#    'American',
#    'minister',
#    'and',
#    'sociologist',
#    '.'],
#   'h': ['charles richmond henderson', 'Q5082045', [[0, 1, 2]]],
#   't': ['minister', 'Q1423891', [[9]]]},
#  {'tokens': ['Born',
#    'in',
#    'Prague',
#    'during',
#    'the',
#    'war',
#    ',',
#    'Karol',
#    'Sidon',
#    'is',
#    'a',
#    'distant',
#    'relative',
#    'of',
#    'rabbi',
#    'Yosef',
#    'Chaim',
#    'Sonnenfeld',
#    '.'],
#   'h': ['yosef chaim sonnenfeld', 'Q1706746', [[15, 16, 17]]],
#   't': ['rabbi', 'Q133485', [[14]]]},
#  {'tokens': ['John',
#    'Jay',
#    'Lee',
#    '(',
#    'born',
#    'August',
#    '20',
#    ',',
#    '1955',
#    ')',
#    'is',
#    'an',
#    'American',
#    'entrepreneur',
#    'and',
#    'politician',
#    '.'],
#   'h': ['john jay lee', 'Q6241714', [[0, 1, 2]]],
#   't': ['politician', 'Q82955', [[15]]]},
#  {'tokens': ['Hans',
#    'Dirk',
#    'de',
#    'Vries',
#    'Reilingh',
#    '(',
#    'Groningen',
#    ',',
#    'August',
#    '22',
#    ',',
#    '1908',
#    '-',
#    'Naarden',
#    ',',
#    'April',
#    '18',
#    ',',
#    '2001',
#    ')',
#    'was',
#    'a',
#    'Dutch',
#    'geographer',
#    'and',
#    'professor',
#    '.'],
#   'h': ['hans dirk de vries reilingh', 'Q19587638', [[0, 1, 2, 3, 4]]],
#   't': ['geographer', 'Q901402', [[23]]]},
#  {'tokens': ['Cameron',
#    'Richardson',
#    '(',
#    'born',
#    'September',
#    '11',
#    ',',
#    '1979',
#    ')',
#    'is',
#    'an',
#    'American',
#    'actress',
#    'and',
#    'model',
#    ',',
#    'who',
#    'portrayed',
#    'Chloe',
#    'Carter',
#    'on',
#    'the',
#    'CBS',
#    'television',
#    'series',
#    '"',
#    'Harper',
#    "'s",
#    'Island',
#    '"',
#    '.'],
#   'h': ['cameron richardson', 'Q242451', [[0, 1]]],
#   't': ['model', 'Q4610556', [[14]]]},
#  {'tokens': ['André',
#    'Heuzé',
#    ',',
#    'or',
#    'sometimes',
#    'André',
#    'Heuse',
#    ',',
#    '(',
#    'Paris',
#    '5',
#    'December',
#    '1880',
#    '–16',
#    'August',
#    '1942',
#    ')',
#    'was',
#    'a',
#    'French',
#    'movie',
#    'director',
#    ',',
#    'screenwriter',
#    'and',
#    'playwright',
#    '.'],
#   'h': ['andré heuzé', 'Q2847959', [[0, 1]]],
#   't': ['movie director', 'Q2526255', [[20, 21]]]},
#  {'tokens': ['Daniel',
#    'Schwenter',
#    '(',
#    'Schwender',
#    ')',
#    '(',
#    '31',
#    'January',
#    '1585',
#    '–',
#    '19',
#    'January',
#    '1636',
#    ')',
#    'was',
#    'a',
#    'German',
#    'Orientalist',
#    ',',
#    'mathematician',
#    ',',
#    'inventor',
#    ',',
#    'poet',
#    ',',
#    'and',
#    'librarian',
#    '.'],
#   'h': ['daniel schwenter', 'Q77509', [[0, 1]]],
#   't': ['mathematician', 'Q170790', [[19]]]},
#  {'tokens': ['Before',
#    'his',
#    'marriage',
#    ',',
#    'Friedman',
#    'trained',
#    'for',
#    'four',
#    'years',
#    'with',
#    'voice',
#    'coach',
#    'Seth',
#    'Riggs',
#    'in',
#    'California',
#    '.'],
#   'h': ['seth riggs', 'Q578620', [[12, 13]]],
#   't': ['voice coach', 'Q2350126', [[10, 11]]]},
#  {'tokens': ['Joe',
#    'Turner',
#    "'s",
#    'Come',
#    'and',
#    'Gone',
#    'is',
#    'a',
#    'play',
#    'by',
#    'American',
#    'playwright',
#    'August',
#    'Wilson',
#    '.'],
#   'h': ['august wilson', 'Q764812', [[12, 13]]],
#   't': ['playwright', 'Q214917', [[11]]]},
#  {'tokens': ['Johann',
#    'Ernst',
#    'Fabri',
#    '(',
#    '16',
#    'July',
#    '1755',
#    ',',
#    'Oels',
#    ',',
#    'Silesia',
#    '–',
#    '30',
#    'May',
#    '1825',
#    ',',
#    'Erlangen',
#    ')',
#    'was',
#    'a',
#    'German',
#    'geographer',
#    'and',
#    'statistician',
#    '.'],
#   'h': ['johann ernst fabri', 'Q328314', [[0, 1, 2]]],
#   't': ['geographer', 'Q901402', [[21]]]},
#  {'tokens': ['Gumbel',
#    'is',
#    'the',
#    'third',
#    'man',
#    'to',
#    'serve',
#    'as',
#    'both',
#    'host',
#    'and',
#    'play',
#    '-',
#    'by',
#    '-',
#    'play',
#    'announcer',
#    'for',
#    'Super',
#    'Bowls',
#    '(',
#    'the',
#    'first',
#    'two',
#    'were',
#    'Dick',
#    'Enberg',
#    'and',
#    'Al',
#    'Michaels',
#    'respectively',
#    ')',
#    '.'],
#   'h': ['al michaels', 'Q978633', [[28, 29]]],
#   't': ['play-by-play', 'Q2986228', [[11, 12, 13, 14, 15]]]},
#  {'tokens': ['She',
#    'is',
#    'a',
#    'member',
#    'of',
#    'the',
#    'Japanese',
#    'idol',
#    'duo',
#    'YuiKaori',
#    'with',
#    'Kaori',
#    'Ishihara',
#    ',',
#    'and',
#    'was',
#    'part',
#    'of',
#    'the',
#    'idol',
#    'unit',
#    'StylipS',
#    '(',
#    'also',
#    'with',
#    'Kaori',
#    ',',
#    'along',
#    'with',
#    'Arisa',
#    'Noto',
#    'and',
#    'Maho',
#    'Matsunaga',
#    ')',
#    '.'],
#   'h': ['maho matsunaga', 'Q2117614', [[32, 33]]],
#   't': ['japanese idol', 'Q226008', [[6, 7]]]},
#  {'tokens': ['Hyman',
#    'Judah',
#    'Schachtel',
#    '(',
#    '1907–1990',
#    ')',
#    'was',
#    'Senior',
#    'Rabbi',
#    'of',
#    'Congregation',
#    'Beth',
#    'Israel',
#    'of',
#    'Houston',
#    'from',
#    '1943',
#    'to',
#    '1975',
#    '.'],
#   'h': ['hyman judah schachtel', 'Q5956373', [[0, 1, 2]]],
#   't': ['rabbi', 'Q133485', [[8]]]},
#  {'tokens': ['Stephanie',
#    'Rose',
#    'Bertram',
#    ',',
#    'or',
#    'Stephanie',
#    'Bertram',
#    '-',
#    'Rose',
#    ',',
#    'most',
#    'commonly',
#    'known',
#    'as',
#    'Rose',
#    'Bertram',
#    '(',
#    'born',
#    '26',
#    'October',
#    '1994',
#    ')',
#    ',',
#    'is',
#    'a',
#    'Belgian',
#    'model',
#    '.'],
#   'h': ['stephanie rose bertram', 'Q21813314', [[0, 1, 2]]],
#   't': ['model', 'Q4610556', [[26]]]},
#  {'tokens': ['Artur',
#    'Soares',
#    'Dias',
#    'of',
#    'Porto',
#    'was',
#    'named',
#    'as',
#    'referee',
#    'for',
#    'the',
#    'match',
#    'on',
#    'the',
#    '8',
#    'August',
#    '.'],
#   'h': ['artur soares dias', 'Q3487305', [[0, 1, 2]]],
#   't': ['referee', 'Q859528', [[8]]]},
#  {'tokens': ['Dilek',
#    'Koçbay',
#    '(',
#    'born',
#    'Dilek',
#    'Özdemir',
#    'on',
#    'December',
#    '30',
#    ',',
#    '1982',
#    ')',
#    ',',
#    'is',
#    'a',
#    'Turkish',
#    'FIFA',
#    'listed',
#    'football',
#    'referee',
#    '.'],
#   'h': ['dilek koçbay', 'Q18713118', [[0, 1]]],
#   't': ['football referee', 'Q859528', [[18, 19]]]},
#  {'tokens': ['She',
#    'also',
#    'collaborated',
#    'with',
#    'a',
#    'variety',
#    'of',
#    'engineers',
#    ',',
#    'including',
#    'Nick',
#    'Launay',
#    ',',
#    'who',
#    'had',
#    'previously',
#    'worked',
#    'with',
#    'artists',
#    'such',
#    'as',
#    'Public',
#    'Image',
#    'Ltd',
#    'and',
#    'Phil',
#    'Collins',
#    '.'],
#   'h': ['nick launay', 'Q248528', [[10, 11]]],
#   't': ['engineers', 'Q128124', [[7]]]},
#  {'tokens': ['In',
#    'the',
#    'United',
#    'States',
#    ',',
#    'the',
#    'work',
#    'of',
#    'Martin',
#    'Seligman',
#    ',',
#    'a',
#    'psychologist',
#    'at',
#    'the',
#    'University',
#    'of',
#    'Pennsylvania',
#    'has',
#    'been',
#    'influential',
#    '.'],
#   'h': ['martin seligman', 'Q320927', [[8, 9]]],
#   't': ['psychologist', 'Q212980', [[12]]]},
#  {'tokens': ['On',
#    '20',
#    'August',
#    '2012',
#    ',',
#    'Malenchenko',
#    'together',
#    'with',
#    'cosmonaut',
#    'Gennady',
#    'Padalka',
#    'participated',
#    'in',
#    'his',
#    'fifth',
#    'career',
#    'spacewalk',
#    '.'],
#   'h': ['gennady padalka', 'Q362998', [[9, 10]]],
#   't': ['cosmonaut', 'Q11631', [[8]]]},
#  {'tokens': ['Michael',
#    'Jackman',
#    '(',
#    'born',
#    'December',
#    '26',
#    ',',
#    '1956',
#    ')',
#    'is',
#    'an',
#    'American',
#    'columnist',
#    ',',
#    'poet',
#    ',',
#    'essayist',
#    ',',
#    'fiction',
#    'writer',
#    ',',
#    'and',
#    'college',
#    'professor',
#    '.'],
#   'h': ['michael jackman', 'Q6831543', [[0, 1]]],
#   't': ['columnist', 'Q1086863', [[12]]]},
#  {'tokens': ['On',
#    'these',
#    'occasion',
#    'opposed',
#    'the',
#    'proposals',
#    'of',
#    'rabbi',
#    'Yitzchak',
#    'Yaacov',
#    'Reines',
#    'to',
#    'choose',
#    'the',
#    'German',
#    'language',
#    'as',
#    'national',
#    'language',
#    'of',
#    'the',
#    'Jewish',
#    'people',
#    'and',
#    'insisted',
#    'on',
#    'the',
#    'primacy',
#    'of',
#    'the',
#    'Hebrew',
#    'language',
#    '.'],
#   'h': ['yitzchak yaacov reines', 'Q941726', [[8, 9, 10]]],
#   't': ['rabbi', 'Q133485', [[7]]]},
#  {'tokens': ['Michael',
#    'Spindelegger',
#    '(',
#    'born',
#    '21',
#    'December',
#    '1959',
#    ')',
#    'is',
#    'an',
#    'Austrian',
#    'politician',
#    '.'],
#   'h': ['michael spindelegger', 'Q11735', [[0, 1]]],
#   't': ['politician', 'Q82955', [[11]]]},
#  {'tokens': ['Katar',
#    'Hol',
#    'is',
#    'an',
#    'honored',
#    'police',
#    'officer',
#    'on',
#    'his',
#    'homeworld',
#    'of',
#    'Thanagar',
#    '.'],
#   'h': ['katar hol', 'Q3783774', [[0, 1]]],
#   't': ['police officer', 'Q384593', [[5, 6]]]},
#  {'tokens': ['Spanish',
#    '–',
#    'Filipino',
#    'footballer',
#    'Carli',
#    'de',
#    'Murga',
#    'of',
#    'Global',
#    'was',
#    'awarded',
#    'the',
#    'inaugural',
#    'Golden',
#    'Ball',
#    'for',
#    'the',
#    'first',
#    'division',
#    '.'],
#   'h': ['carli de murga', 'Q5041282', [[4, 5, 6]]],
#   't': ['footballer', 'Q937857', [[3]]]},
#  {'tokens': ['Ernie',
#    'Parsons',
#    '(',
#    'born',
#    'June',
#    '5',
#    ',',
#    '1946',
#    ')',
#    'is',
#    'a',
#    'former',
#    'politician',
#    'in',
#    'Ontario',
#    ',',
#    'Canada',
#    '.'],
#   'h': ['ernie parsons', 'Q5394680', [[0, 1]]],
#   't': ['politician', 'Q82955', [[12]]]},
#  {'tokens': ['The',
#    'only',
#    'life',
#    'sentence',
#    'for',
#    'a',
#    'single',
#    'murder',
#    'without',
#    'gravitating',
#    'circumstances',
#    'was',
#    'given',
#    'in',
#    '2005',
#    'to',
#    'Mohammed',
#    'Bouyeri',
#    'for',
#    'the',
#    'murder',
#    'of',
#    'Dutch',
#    'film',
#    'director',
#    'Theo',
#    'van',
#    'Gogh',
#    ',',
#    'due',
#    'to',
#    'its',
#    'strong',
#    'political',
#    'nature',
#    '.'],
#   'h': ['theo van gogh', 'Q205456', [[25, 26, 27]]],
#   't': ['film director', 'Q2526255', [[23, 24]]]},
#  {'tokens': ['He',
#    'broke',
#    'off',
#    'his',
#    'traditional',
#    'religious',
#    'schooling',
#    'to',
#    'join',
#    'the',
#    'theatre',
#    'company',
#    'of',
#    'the',
#    'cultural',
#    'organisation',
#    '"',
#    'Hazomir',
#    '"',
#    '(',
#    'Hebrew',
#    'for',
#    '“',
#    'nightingale',
#    '”',
#    ')',
#    ',',
#    'led',
#    'by',
#    'the',
#    'author',
#    'Isaac',
#    'Leib',
#    'Peretz',
#    '.'],
#   'h': ['isaac leib peretz', 'Q425644', [[31, 32, 33]]],
#   't': ['author', 'Q36180', [[30]]]},
#  {'tokens': ['Michele',
#    'Merlo',
#    '(',
#    'born',
#    '7',
#    'August',
#    '1984',
#    ')',
#    'is',
#    'an',
#    'Italian',
#    'professional',
#    'racing',
#    'cyclist',
#    ',',
#    'who',
#    'last',
#    'rode',
#    'for',
#    'the',
#    'UCI',
#    'Professional',
#    'Continental',
#    'team',
#    '.'],
#   'h': ['michele merlo', 'Q617842', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[12, 13]]]},
#  {'tokens': ['In',
#    'January',
#    '2017',
#    ',',
#    'the',
#    'Gophers',
#    'fired',
#    'head',
#    'coach',
#    'Tracy',
#    'Claeys',
#    'and',
#    'hired',
#    'former',
#    'Western',
#    'Michigan',
#    'head',
#    'coach',
#    'P.',
#    'J.',
#    'Fleck',
#    'as',
#    'the',
#    'new',
#    'head',
#    'coach',
#    '.'],
#   'h': ['tracy claeys', 'Q16198199', [[9, 10]]],
#   't': ['head coach', 'Q3246315', [[7, 8], [16, 17], [24, 25]]]},
#  {'tokens': ['Matt',
#    'Greenberg',
#    'is',
#    'an',
#    'American',
#    'screenwriter',
#    'and',
#    'producer',
#    ',',
#    'most',
#    'notable',
#    'for',
#    'his',
#    'work',
#    'on',
#    'the',
#    'horror',
#    'films',
#    '"',
#    '"',
#    'and',
#    '"',
#    '1408',
#    '"',
#    '.'],
#   'h': ['matt greenberg', 'Q6788727', [[0, 1]]],
#   't': ['screenwriter', 'Q28389', [[5]]]},
#  {'tokens': ['Ingrid',
#    'Lehmann',
#    'is',
#    'a',
#    'former',
#    'East',
#    'German',
#    'figure',
#    'skater',
#    'and',
#    'coach',
#    ',',
#    'who',
#    'taught',
#    'Simone',
#    'Koch',
#    'and',
#    'Hermann',
#    'Schulz',
#    'in',
#    'the',
#    '1980s',
#    'in',
#    'Berlin',
#    '.'],
#   'h': ['ingrid lehmann', 'Q1663352', [[0, 1]]],
#   't': ['coach', 'Q41583', [[10]]]},
#  {'tokens': ['Verena',
#    'Mei',
#    '(',
#    'born',
#    'November',
#    '2',
#    'in',
#    'Pearl',
#    'City',
#    ',',
#    'Hawaii',
#    ')',
#    'is',
#    'an',
#    'American',
#    'model',
#    ',',
#    'actress',
#    'and',
#    'racecar',
#    'driver',
#    'of',
#    'Asian',
#    '-',
#    'American',
#    'descent',
#    '.'],
#   'h': ['verena mei', 'Q7921217', [[0, 1]]],
#   't': ['model', 'Q4610556', [[15]]]},
#  {'tokens': ['Jacques',
#    'Ovyn',
#    '(',
#    'or',
#    'Ouyn',
#    ')',
#    ',',
#    'born',
#    'in',
#    'Louviers',
#    '(',
#    'Normandy',
#    ')',
#    ',',
#    'was',
#    'a',
#    '16th',
#    '-',
#    'century',
#    'French',
#    'playwright',
#    '.'],
#   'h': ['jacques ovyn', 'Q3159701', [[0, 1]]],
#   't': ['playwright', 'Q214917', [[20]]]},
#  {'tokens': ['Bertel',
#    'Broman',
#    '(',
#    '21',
#    'August',
#    '1889',
#    '–',
#    '11',
#    'May',
#    '1952',
#    ')',
#    'was',
#    'a',
#    'Finnish',
#    'sailor',
#    'who',
#    'competed',
#    'in',
#    'the',
#    '1928',
#    'Summer',
#    'Olympics',
#    '.'],
#   'h': ['bertel broman', 'Q3381094', [[0, 1]]],
#   't': ['sailor', 'Q476246', [[14]]]},
#  {'tokens': ['Víctor',
#    'Morlán',
#    'Gracia',
#    '(',
#    'born',
#    '9',
#    'May',
#    '1947',
#    ')',
#    'is',
#    'a',
#    'Spanish',
#    'politician',
#    '.'],
#   'h': ['víctor morlán gracia', 'Q11705211', [[0, 1, 2]]],
#   't': ['politician', 'Q82955', [[12]]]},
#  {'tokens': ['He',
#    'was',
#    'the',
#    'father',
#    'of',
#    'archaeologist',
#    'Alexandre',
#    'Bertrand',
#    '(',
#    '1820–1902',
#    ')',
#    'and',
#    'mathematician',
#    'Joseph',
#    'Bertrand',
#    '(',
#    '1822–1900',
#    ')',
#    '.'],
#   'h': ['joseph bertrand', 'Q315436', [[13, 14]]],
#   't': ['mathematician', 'Q170790', [[12]]]},
#  {'tokens': ['Samat',
#    'Smakov',
#    '(;',
#    'Russian',
#    ':',
#    'Самат',
#    'Смаков',
#    ';',
#    'born',
#    '8',
#    'December',
#    '1978',
#    'in',
#    'Semey',
#    ')',
#    'is',
#    'a',
#    'retired',
#    'Kazakhstani',
#    'footballer',
#    'who',
#    'played',
#    'as',
#    'a',
#    'defender',
#    '.'],
#   'h': ['samat smakov', 'Q970546', [[0, 1]]],
#   't': ['footballer', 'Q937857', [[19]]]},
#  {'tokens': ['Dušan',
#    'Trančík',
#    '(',
#    'born',
#    '26',
#    'November',
#    '1946',
#    ')',
#    'is',
#    'a',
#    'Slovak',
#    'film',
#    'director',
#    'and',
#    'screenwriter',
#    '.'],
#   'h': ['dušan trančík', 'Q5317753', [[0, 1]]],
#   't': ['film director', 'Q2526255', [[11, 12]]]},
#  {'tokens': ['Ole',
#    'Fogh',
#    'Kirkeby',
#    '(',
#    'born',
#    '1947',
#    ')',
#    'is',
#    'a',
#    'Danish',
#    'philosopher',
#    'and',
#    'a',
#    'professor',
#    'at',
#    'Copenhagen',
#    'Business',
#    'School',
#    'in',
#    'the',
#    'Philosophy',
#    'of',
#    'Leadership',
#    '.'],
#   'h': ['ole fogh kirkeby', 'Q7085837', [[0, 1, 2]]],
#   't': ['philosopher', 'Q4964182', [[10]]]},
#  {'tokens': ['The',
#    'decision',
#    'to',
#    'name',
#    'Cleveland',
#    'the',
#    'host',
#    'city',
#    'was',
#    'announced',
#    'on',
#    'January',
#    '27',
#    ',',
#    '2017',
#    'by',
#    'Major',
#    'League',
#    'Baseball',
#    'Commissioner',
#    'Rob',
#    'Manfred',
#    '.'],
#   'h': ['rob manfred', 'Q16499788', [[20, 21]]],
#   't': ['commissioner', 'Q1051088', [[19]]]},
#  {'tokens': ['Elisabeth',
#    'Bouchaud',
#    '(',
#    'born',
#    'Tibi',
#    ')',
#    'is',
#    'a',
#    'French',
#    'physicist',
#    ',',
#    'playwright',
#    'and',
#    'actress',
#    'born',
#    '1',
#    'March',
#    '1961',
#    '.'],
#   'h': ['elisabeth bouchaud', 'Q19609766', [[0, 1]]],
#   't': ['playwright', 'Q214917', [[11]]]},
#  {'tokens': ['Yvon',
#    'Poitras',
#    '(',
#    'born',
#    'July',
#    '13',
#    ',',
#    '1948',
#    'in',
#    'Grand',
#    'Falls',
#    ',',
#    'New',
#    'Brunswick',
#    ')',
#    'is',
#    'a',
#    'Canadian',
#    'businessman',
#    ',',
#    'politician',
#    'and',
#    'lobbyist',
#    '.'],
#   'h': ['yvon poitras', 'Q3574145', [[0, 1]]],
#   't': ['politician', 'Q82955', [[20]]]},
#  {'tokens': ['Adalet',
#    'Ağaoğlu',
#    '(',
#    'née',
#    'Sümer',
#    'in',
#    '1929',
#    ')',
#    'is',
#    'a',
#    'Turkish',
#    'novelist',
#    'and',
#    'playwright',
#    '.'],
#   'h': ['adalet ağaoğlu', 'Q348117', [[0, 1]]],
#   't': ['playwright', 'Q214917', [[13]]]},
#  {'tokens': ['Michael',
#    'Pattinson',
#    '(',
#    'born',
#    '1957',
#    ')',
#    'is',
#    'an',
#    'Australian',
#    'film',
#    'director',
#    '.'],
#   'h': ['michael pattinson', 'Q6833415', [[0, 1]]],
#   't': ['film director', 'Q2526255', [[9, 10]]]},
#  {'tokens': ['Don',
#    'Cummings',
#    '(',
#    'born',
#    'August',
#    '3',
#    ')',
#    'is',
#    'an',
#    'American',
#    'playwright',
#    'of',
#    'more',
#    'than',
#    'fifteen',
#    'plays',
#    ',',
#    'a',
#    'screenwriter',
#    ',',
#    'fiction',
#    'writer',
#    ',',
#    'essayist',
#    ',',
#    'actor',
#    ',',
#    'and',
#    'composer',
#    '.'],
#   'h': ['don cummings', 'Q5292473', [[0, 1]]],
#   't': ['playwright', 'Q214917', [[10]]]},
#  {'tokens': ['Torsten',
#    'Gowitzke',
#    '(',
#    'born',
#    '8',
#    'January',
#    '1967',
#    ')',
#    'is',
#    'a',
#    'German',
#    'football',
#    'manager',
#    'and',
#    'former',
#    'player',
#    '.'],
#   'h': ['torsten gowitzke', 'Q1423256', [[0, 1]]],
#   't': ['manager', 'Q628099', [[12]]]},
#  {'tokens': ['Pilar',
#    'Lastra',
#    '(',
#    'born',
#    'January',
#    '15',
#    ',',
#    '1981',
#    ')',
#    'is',
#    'a',
#    'model',
#    'and',
#    'the',
#    '"',
#    'Playboy',
#    '"',
#    'Playmate',
#    'of',
#    'the',
#    'Month',
#    'for',
#    'August',
#    '2004',
#    '.'],
#   'h': ['pilar lastra', 'Q3388381', [[0, 1]]],
#   't': ['model', 'Q4610556', [[11]]]},
#  {'tokens': ['Peter',
#    'Gatkuoth',
#    '(',
#    'died',
#    '2010',
#    ')',
#    'was',
#    'a',
#    'South',
#    'Sudanese',
#    'politician',
#    '.'],
#   'h': ['peter gatkuoth', 'Q7174190', [[0, 1]]],
#   't': ['politician', 'Q82955', [[10]]]},
#  {'tokens': ['The',
#    'World',
#    '(',
#    ')',
#    'is',
#    'a',
#    '2004',
#    'Chinese',
#    'film',
#    'written',
#    'and',
#    'directed',
#    'by',
#    'Jia',
#    'Zhangke',
#    '.'],
#   'h': ['jia zhangke', 'Q461079', [[13, 14]]],
#   't': ['directed', 'Q2526255', [[11]]]},
#  {'tokens': ['Georgios',
#    'Pangalos',
#    '(',
#    'born',
#    '21',
#    'June',
#    '1936',
#    ')',
#    'is',
#    'a',
#    'Greek',
#    'former',
#    'sports',
#    'shooter',
#    '.'],
#   'h': ['georgios pangalos', 'Q23682572', [[0, 1]]],
#   't': ['sports shooter', 'Q17486376', [[12, 13]]]},
#  {'tokens': ['The',
#    'epic',
#    'film',
#    'boasted',
#    '1,186',
#    'supporting',
#    'players',
#    'performing',
#    'on',
#    'fifty',
#    '-',
#    'four',
#    'sets',
#    'designed',
#    'by',
#    'art',
#    'director',
#    'Anton',
#    'Grot',
#    'and',
#    'his',
#    'assistant',
#    'Leo',
#    'Kuter',
#    '.'],
#   'h': ['anton grot', 'Q589834', [[17, 18]]],
#   't': ['art director', 'Q706364', [[15, 16]]]},
#  {'tokens': ['Punk',
#    'Rock',
#    'is',
#    'a',
#    'play',
#    'by',
#    'the',
#    'British',
#    'playwright',
#    'Simon',
#    'Stephens',
#    'which',
#    'premiered',
#    'at',
#    'the',
#    'Royal',
#    'Exchange',
#    'in',
#    '2009',
#    'and',
#    'transferred',
#    'to',
#    'the',
#    'Lyric',
#    'Hammersmith',
#    'directed',
#    'by',
#    'Sarah',
#    'Frankcom',
#    '.'],
#   'h': ['simon stephens', 'Q363488', [[9, 10]]],
#   't': ['playwright', 'Q214917', [[8]]]},
#  {'tokens': ['Riki',
#    'Kobayashi',
#    '(',
#    '1924–2013',
#    ')',
#    'was',
#    'a',
#    'chemical',
#    'engineer',
#    'and',
#    'a',
#    'long',
#    '-',
#    'time',
#    'professor',
#    'of',
#    'chemical',
#    'engineering',
#    'at',
#    'Rice',
#    'University',
#    '.'],
#   'h': ['riki kobayashi', 'Q18630900', [[0, 1]]],
#   't': ['chemical engineer', 'Q7888586', [[7, 8]]]},
#  {'tokens': ['Knut',
#    'Agathon',
#    'Wallenberg',
#    '(',
#    '19',
#    'May',
#    '1853',
#    '–',
#    '1',
#    'June',
#    '1938',
#    ')',
#    'was',
#    'a',
#    'Swedish',
#    'banker',
#    'and',
#    'politician',
#    ',',
#    'he',
#    'was',
#    'also',
#    'a',
#    'Knight',
#    'of',
#    'the',
#    'Order',
#    'of',
#    'the',
#    'Seraphim',
#    '.'],
#   'h': ['knut agathon wallenberg', 'Q156797', [[0, 1, 2]]],
#   't': ['politician', 'Q82955', [[17]]]},
#  {'tokens': ['The',
#    'album',
#    'includes',
#    'a',
#    'cover',
#    'of',
#    'Joan',
#    'Baez',
#    "'",
#    '"',
#    'Diamonds',
#    '&',
#    'Rust',
#    '"',
#    ',',
#    'a',
#    'decision',
#    'which',
#    'was',
#    'encouraged',
#    'by',
#    'producer',
#    'Roger',
#    'Glover',
#    'in',
#    'the',
#    'interest',
#    'of',
#    'adding',
#    'a',
#    'more',
#    'commercial',
#    'track',
#    '.'],
#   'h': ['roger glover', 'Q216700', [[22, 23]]],
#   't': ['producer', 'Q183945', [[21]]]},
#  {'tokens': ['El',
#    'Lago',
#    'has',
#    'particular',
#    'historical',
#    'significance',
#    'as',
#    'it',
#    'sits',
#    'on',
#    'the',
#    'site',
#    'of',
#    'one',
#    'of',
#    'the',
#    'main',
#    'hide',
#    '-',
#    'outs',
#    'for',
#    'the',
#    'French',
#    'pirate',
#    'and',
#    'privateer',
#    'Jean',
#    'Lafitte',
#    '.'],
#   'h': ['jean lafitte', 'Q454672', [[26, 27]]],
#   't': ['privateer', 'Q201559', [[25]]]},
#  {'tokens': ['His',
#    'paternal',
#    'aunt',
#    ',',
#    'Queen',
#    'Sofía',
#    'of',
#    'Spain',
#    ',',
#    'was',
#    'Queen',
#    'Consort',
#    'of',
#    'Spain',
#    '.'],
#   'h': ['queen sofía of spain', 'Q156548', [[4, 5, 6, 7]]],
#   't': ['queen consort', 'Q719039', [[10, 11]]]},
#  {'tokens': ['Guido',
#    'Van',
#    'Calster',
#    '(',
#    'born',
#    '6',
#    'February',
#    '1956',
#    ')',
#    'is',
#    'a',
#    'retired',
#    'Belgian',
#    'racing',
#    'cyclist',
#    '.'],
#   'h': ['guido van calster', 'Q531117', [[0, 1, 2]]],
#   't': ['racing cyclist', 'Q2309784', [[13, 14]]]},
#  {'tokens': ['Jonas',
#    'Kubilius',
#    '(',
#    '27',
#    'July',
#    '1921',
#    '–',
#    '30',
#    'October',
#    '2011',
#    ')',
#    'was',
#    'a',
#    'Lithuanian',
#    'mathematician',
#    'who',
#    'worked',
#    'in',
#    'probability',
#    'theory',
#    'and',
#    'number',
#    'theory',
#    '.'],
#   'h': ['jonas kubilius', 'Q1702987', [[0, 1]]],
#   't': ['mathematician', 'Q170790', [[14]]]},
#  {'tokens': ['Alhaji',
#    'Andrew',
#    'Kanu',
#    'is',
#    'a',
#    'Sierra',
#    'Leonean',
#    'politician',
#    'from',
#    'Makeni',
#    ',',
#    'Bombali',
#    'District',
#    '.'],
#   'h': ['andrew kanu', 'Q4757573', [[1, 2]]],
#   't': ['politician', 'Q82955', [[7]]]},
#  {'tokens': ['Eric',
#    'Bach',
#    'is',
#    'an',
#    'American',
#    'computer',
#    'scientist',
#    'who',
#    'has',
#    'made',
#    'contributions',
#    'to',
#    'computational',
#    'number',
#    'theory',
#    '.'],
#   'h': ['eric bach', 'Q5386065', [[0, 1]]],
#   't': ['computer scientist', 'Q82594', [[5, 6]]]},
#  {'tokens': ['Charles',
#    'Maigne',
#    '(',
#    'November',
#    '11',
#    ',',
#    '1879',
#    '–',
#    'November',
#    '28',
#    ',',
#    '1929',
#    ')',
#    'was',
#    'an',
#    'American',
#    'screenwriter',
#    'and',
#    'film',
#    'director',
#    'of',
#    'the',
#    'silent',
#    'era',
#    '.'],
#   'h': ['charles maigne', 'Q1123531', [[0, 1]]],
#   't': ['film director', 'Q2526255', [[18, 19]]]},
#  {'tokens': ['Heartbeat',
#    'Radio',
#    'is',
#    'the',
#    'fifth',
#    'album',
#    'by',
#    'Norwegian',
#    'singer',
#    '-',
#    'songwriter',
#    'and',
#    'guitarist',
#    'Sondre',
#    'Lerche',
#    '.'],
#   'h': ['sondre lerche', 'Q726295', [[13, 14]]],
#   't': ['guitarist', 'Q855091', [[12]]]},
#  {'tokens': ['He',
#    'took',
#    'up',
#    'the',
#    'post',
#    'of',
#    'caretaker',
#    'manager',
#    'at',
#    'Wrexham',
#    'after',
#    'the',
#    'departure',
#    'of',
#    'Andy',
#    'Morrell',
#    'as',
#    'manager',
#    ',',
#    'but',
#    'failed',
#    'to',
#    'secure',
#    'the',
#    'position',
#    'permanently',
#    '.'],
#   'h': ['andy morrell', 'Q3404769', [[14, 15]]],
#   't': ['manager', 'Q628099', [[7], [17]]]},
#  {'tokens': ['John',
#    'Weider',
#    '(',
#    'born',
#    '21',
#    'April',
#    '1947',
#    'in',
#    'Shepherd',
#    "'s",
#    'Bush',
#    ',',
#    'London',
#    ')',
#    'is',
#    'an',
#    'English',
#    'rock',
#    'musician',
#    'who',
#    'plays',
#    'guitar',
#    ',',
#    'bass',
#    ',',
#    'and',
#    'violin',
#    '.'],
#   'h': ['john weider', 'Q3182708', [[0, 1]]],
#   't': ['musician', 'Q639669', [[18]]]},
#  {'tokens': ['Silvano',
#    'Schiavon',
#    '(',
#    '4',
#    'November',
#    '1942',
#    '–',
#    '21',
#    'October',
#    '1977',
#    ')',
#    'was',
#    'an',
#    'Italian',
#    'racing',
#    'cyclist',
#    '.'],
#   'h': ['silvano schiavon', 'Q3483971', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[14, 15]]]},
#  {'tokens': ['Comic',
#    "'s",
#    'Choice',
#    'is',
#    'a',
#    'British',
#    'comedy',
#    'chat',
#    'show',
#    'hosted',
#    'by',
#    'the',
#    'comedian',
#    'Bill',
#    'Bailey',
#    ',',
#    'and',
#    'broadcast',
#    'on',
#    'Channel',
#    '4',
#    '.'],
#   'h': ['bill bailey', 'Q944744', [[13, 14]]],
#   't': ['comedian', 'Q18545066', [[12]]]},
#  {'tokens': ['Zeev',
#    'Suraski',
#    '(',
#    ')',
#    'is',
#    'an',
#    'Israeli',
#    'programmer',
#    ',',
#    'PHP',
#    'developer',
#    'and',
#    'co',
#    '-',
#    'founder',
#    'of',
#    'Zend',
#    'Technologies',
#    '.'],
#   'h': ['zeev suraski', 'Q64050', [[0, 1]]],
#   't': ['programmer', 'Q5482740', [[7]]]},
#  {'tokens': ['Marcel',
#    'Renaud',
#    '(',
#    '28',
#    'September',
#    '1900',
#    '–',
#    '17',
#    'June',
#    '1968',
#    ')',
#    'was',
#    'a',
#    'French',
#    'racing',
#    'cyclist',
#    'who',
#    'competed',
#    'in',
#    'the',
#    'mid-1920s',
#    '.'],
#   'h': ['marcel renaud', 'Q15646937', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[14, 15]]]},
#  {'tokens': ['Castle',
#    'of',
#    'Doom',
#    'Studios',
#    ',',
#    'created',
#    'in',
#    '2005',
#    'by',
#    'record',
#    'producer',
#    'Tony',
#    'Doogan',
#    'and',
#    'Mogwai',
#    ',',
#    'is',
#    'a',
#    'recording',
#    'studio',
#    'in',
#    'Glasgow',
#    ',',
#    'Scotland',
#    '.'],
#   'h': ['tony doogan', 'Q17385850', [[11, 12]]],
#   't': ['record producer', 'Q183945', [[9, 10]]]},
#  {'tokens': ['Abdul',
#    'Haseeb',
#    'Khan',
#    '(',
#    'Urdu',
#    ':',
#    'عبدل',
#    'حسیب',
#    'خان',
#    ')',
#    'is',
#    'a',
#    'Pakistani',
#    'Politician',
#    'and',
#    'a',
#    'Member',
#    'of',
#    'Senate',
#    'of',
#    'Pakistan',
#    '.'],
#   'h': ['abdul haseeb khan', 'Q18683749', [[0, 1, 2]]],
#   't': ['politician', 'Q82955', [[13]]]},
#  {'tokens': ['Jerzy',
#    'Skolimowski',
#    '(',
#    ',',
#    'born',
#    '5',
#    'May',
#    '1938',
#    ')',
#    'is',
#    'a',
#    'Polish',
#    'film',
#    'director',
#    ',',
#    'screenwriter',
#    ',',
#    'dramatist',
#    'and',
#    'actor',
#    '.'],
#   'h': ['jerzy skolimowski', 'Q51530', [[0, 1]]],
#   't': ['film director', 'Q2526255', [[12, 13]]]},
#  {'tokens': ['Garçon',
#    'stupide',
#    '(',
#    'English',
#    ':',
#    '"',
#    'Stupid',
#    'Boy',
#    '"',
#    ')',
#    'is',
#    'a',
#    '2004',
#    'film',
#    'directed',
#    'by',
#    'Lionel',
#    'Baier',
#    '.'],
#   'h': ['lionel baier', 'Q3241813', [[16, 17]]],
#   't': ['directed', 'Q2526255', [[14]]]},
#  {'tokens': ['Karsten',
#    'Magnus',
#    'Konow',
#    '(',
#    '16',
#    'February',
#    '1918',
#    '–',
#    '10',
#    'July',
#    '1945',
#    ')',
#    'was',
#    'a',
#    'Norwegian',
#    'sailor',
#    'who',
#    'competed',
#    'in',
#    'the',
#    '1936',
#    'Summer',
#    'Olympics',
#    '.'],
#   'h': ['magnus konow', 'Q3843384', [[1, 2]]],
#   't': ['sailor', 'Q476246', [[15]]]},
#  {'tokens': ['Damir',
#    'Salimov',
#    'was',
#    'the',
#    'film',
#    "'s",
#    'director',
#    'and',
#    'the',
#    'script',
#    'was',
#    'written',
#    'by',
#    'Shukhrat',
#    'Abbasov',
#    'and',
#    'Alexander',
#    'Naumov',
#    '.'],
#   'h': ['damir salimov', 'Q4405823', [[0, 1]]],
#   't': ['director', 'Q2526255', [[6]]]},
#  {'tokens': ['Kent',
#    'Härstedt',
#    '(',
#    'born',
#    '29',
#    'January',
#    '1965',
#    'in',
#    'Helsingborg',
#    ')',
#    'is',
#    'a',
#    'Swedish',
#    'social',
#    'democratic',
#    'politician',
#    ',',
#    'member',
#    'of',
#    'the',
#    'Riksdag',
#    'since',
#    'the',
#    'Swedish',
#    'general',
#    'election',
#    ',',
#    '1998',
#    '.'],
#   'h': ['kent härstedt', 'Q3359013', [[0, 1]]],
#   't': ['politician', 'Q82955', [[15]]]},
#  {'tokens': ['Eugenio',
#    'Barba',
#    '(',
#    'born',
#    '29',
#    'October',
#    '1936',
#    'in',
#    'Brindisi',
#    ',',
#    'Italy',
#    ')',
#    'is',
#    'an',
#    'Italian',
#    'author',
#    'and',
#    'theatre',
#    'director',
#    'based',
#    'in',
#    'Denmark',
#    '.'],
#   'h': ['eugenio barba', 'Q469976', [[0, 1]]],
#   't': ['author', 'Q36180', [[15]]]},
#  {'tokens': ['In',
#    'September',
#    '2011',
#    'he',
#    'was',
#    'appointed',
#    'as',
#    'the',
#    'manager',
#    'of',
#    'Zalaegerszeg',
#    'after',
#    'János',
#    'Csank',
#    'resigned',
#    'from',
#    'his',
#    'position',
#    'due',
#    'to',
#    'an',
#    'unsuccessful',
#    'start',
#    'in',
#    'the',
#    'Hungarian',
#    'League',
#    '.'],
#   'h': ['jános csank', 'Q640939', [[12, 13]]],
#   't': ['manager', 'Q628099', [[8]]]},
#  {'tokens': ['Nasir',
#    'al',
#    '-',
#    'Din',
#    'al',
#    '-',
#    'Tusi',
#    'was',
#    'Persian',
#    'philosopher',
#    ',',
#    'mathematician',
#    ',',
#    'and',
#    'theologian',
#    'that',
#    'was',
#    'born',
#    'into',
#    'Shia',
#    'family',
#    'in',
#    'Tus',
#    'in',
#    '1201',
#    '.'],
#   'h': ['nasir al-din al-tusi', 'Q302835', [[0, 1, 2, 3, 4, 5, 6]]],
#   't': ['philosopher', 'Q4964182', [[9]]]},
#  {'tokens': ['She',
#    'is',
#    'married',
#    'to',
#    'film',
#    'director',
#    'Mohsen',
#    'Makhmalbaf',
#    'who',
#    'wrote',
#    'the',
#    'script',
#    'for',
#    'her',
#    'début',
#    'film',
#    '"',
#    'The',
#    'Day',
#    'I',
#    'Became',
#    'a',
#    'Woman',
#    '"',
#    '.'],
#   'h': ['mohsen makhmalbaf', 'Q55211', [[6, 7]]],
#   't': ['film director', 'Q2526255', [[4, 5]]]},
#  {'tokens': ['Werner',
#    'Lippoldt',
#    '(',
#    'born',
#    '16',
#    'February',
#    '1944',
#    ')',
#    'is',
#    'a',
#    'German',
#    'former',
#    'sport',
#    'shooter',
#    'who',
#    'competed',
#    'in',
#    'the',
#    '1972',
#    'Summer',
#    'Olympics',
#    'winning',
#    'a',
#    'bronze',
#    'medal',
#    '.'],
#   'h': ['werner lippoldt', 'Q1521217', [[0, 1]]],
#   't': ['sport shooter', 'Q17486376', [[12, 13]]]},
#  {'tokens': ['Brian',
#    'Rawling',
#    'is',
#    'a',
#    'British',
#    'record',
#    'producer',
#    'and',
#    'songwriter',
#    '.'],
#   'h': ['brian rawling', 'Q20685269', [[0, 1]]],
#   't': ['songwriter', 'Q753110', [[8]]]},
#  {'tokens': ['Steven',
#    'Ilous',
#    '(',
#    'born',
#    '2',
#    'June',
#    '1981',
#    ')',
#    'is',
#    'a',
#    'director',
#    ',',
#    'writer',
#    ',',
#    'producer',
#    'and',
#    'visual',
#    'effects',
#    'supervisor',
#    'as',
#    'well',
#    'as',
#    'the',
#    'founder',
#    'of',
#    'Monolith',
#    'Pictures',
#    ',',
#    'and',
#    'SMI',
#    'Entertainment',
#    '.'],
#   'h': ['steven ilous', 'Q19667289', [[0, 1]]],
#   't': ['director', 'Q2526255', [[10]]]},
#  {'tokens': ['Alan',
#    'Michael',
#    'Dressler',
#    '(',
#    'born',
#    '23',
#    'March',
#    '1948',
#    ')',
#    'is',
#    'an',
#    'American',
#    'astronomer',
#    'at',
#    'the',
#    'Carnegie',
#    'Institution',
#    'for',
#    'Science',
#    'of',
#    'Washington',
#    ',',
#    'D.C',
#    '..'],
#   'h': ['alan michael dressler', 'Q4706535', [[0, 1, 2]]],
#   't': ['astronomer', 'Q11063', [[12]]]},
#  {'tokens': ['His',
#    'first',
#    'full',
#    'season',
#    '(',
#    '1972',
#    '-',
#    '73',
#    ')',
#    'was',
#    'coincidentally',
#    'the',
#    'last',
#    'one',
#    'for',
#    'another',
#    'Great',
#    'Yarmouth',
#    'referee',
#    'who',
#    'achieved',
#    'honours',
#    '-',
#    'Norman',
#    'Burtenshaw',
#    '.'],
#   'h': ['norman burtenshaw', 'Q1218559', [[23, 24]]],
#   't': ['referee', 'Q859528', [[18]]]},
#  {'tokens': ['Barbro',
#    'Hietala',
#    'Nordlund',
#    ',',
#    'born',
#    '1946',
#    ',',
#    'is',
#    'a',
#    'Swedish',
#    'social',
#    'democratic',
#    'politician',
#    ',',
#    'member',
#    'of',
#    'the',
#    'Riksdag',
#    'first',
#    '1994–1998',
#    'and',
#    'then',
#    'again',
#    '2001–2006',
#    '.'],
#   'h': ['barbro hietala nordlund', 'Q4859750', [[0, 1, 2]]],
#   't': ['politician', 'Q82955', [[12]]]},
#  {'tokens': ['DJ',
#    'Hyper',
#    'is',
#    'a',
#    'British',
#    'DJ',
#    ',',
#    'producer',
#    'and',
#    'remixer',
#    'known',
#    'for',
#    'his',
#    'lliberal',
#    'use',
#    'of',
#    'live',
#    'bass',
#    ',',
#    'guitars',
#    'and',
#    'uncompromising',
#    'vocals',
#    '.'],
#   'h': ['dj hyper', 'Q4036906', [[0, 1]]],
#   't': ['producer', 'Q183945', [[7]]]},
#  {'tokens': ['Heinrich',
#    'Christian',
#    'Beck',
#    '(',
#    '19',
#    'February',
#    '1760',
#    'in',
#    'Gotha',
#    '–',
#    '7',
#    'May',
#    '1803',
#    'in',
#    'Mannheim',
#    ')',
#    'was',
#    'a',
#    'German',
#    'actor',
#    'and',
#    'playwright',
#    '.'],
#   'h': ['heinrich christian beck', 'Q86912', [[0, 1, 2]]],
#   't': ['playwright', 'Q214917', [[21]]]},
#  {'tokens': ['The',
#    'series',
#    'was',
#    'broadcast',
#    'by',
#    'Fox',
#    ',',
#    'and',
#    'the',
#    'announcers',
#    'were',
#    'Joe',
#    'Buck',
#    'and',
#    'Tim',
#    'McCarver',
#    '.'],
#   'h': ['tim mccarver', 'Q7803927', [[14, 15]]],
#   't': ['announcers', 'Q2986228', [[9]]]},
#  {'tokens': ['William',
#    'Frédéric',
#    'Edwards',
#    '(',
#    '1777–1842',
#    ')',
#    'was',
#    'a',
#    'French',
#    'physiologist',
#    ',',
#    'of',
#    'Jamaican',
#    'background',
#    ',',
#    'who',
#    'was',
#    'also',
#    'a',
#    'pioneer',
#    'anthropologist',
#    '.'],
#   'h': ['william frédéric edwards', 'Q2152782', [[0, 1, 2]]],
#   't': ['anthropologist', 'Q4773904', [[20]]]},
#  {'tokens': ['Yonatan',
#    'Yosef',
#    ',',
#    'a',
#    'prominent',
#    'Jerusalem',
#    'rabbi',
#    ',',
#    'is',
#    'the',
#    'spokesman',
#    'for',
#    'Jewish',
#    'settlers',
#    'in',
#    'Sheikh',
#    'Jarrah',
#    ',',
#    'and',
#    'a',
#    'prominent',
#    'activists',
#    'for',
#    'the',
#    'Judaization',
#    'of',
#    'East',
#    'Jerusalem',
#    '.'],
#   'h': ['yonatan yosef', 'Q19595703', [[0, 1]]],
#   't': ['rabbi', 'Q133485', [[6]]]},
#  {'tokens': ['Alexander',
#    'Specker',
#    '(',
#    'born',
#    '30',
#    'June',
#    '1918',
#    ')',
#    'was',
#    'a',
#    'Swiss',
#    'sports',
#    'shooter',
#    '.'],
#   'h': ['alexander specker', 'Q19577944', [[0, 1]]],
#   't': ['sports shooter', 'Q17486376', [[11, 12]]]},
#  {'tokens': ['Among',
#    'Bhoothalingam',
#    "'s",
#    'grandchildren',
#    'is',
#    'the',
#    'distinguished',
#    'paediatrician',
#    'Soumya',
#    'Swaminathan',
#    '.'],
#   'h': ['soumya swaminathan', 'Q21062285', [[8, 9]]],
#   't': ['paediatrician', 'Q1919436', [[7]]]},
#  {'tokens': ['Alfons',
#    'Pawelczyk',
#    '(',
#    'born',
#    '1933',
#    'in',
#    'Parnow',
#    ',',
#    'Province',
#    'of',
#    'Pomerania',
#    ')',
#    'is',
#    'a',
#    'German',
#    'politician',
#    '.'],
#   'h': ['alfons pawelczyk', 'Q99277', [[0, 1]]],
#   't': ['politician', 'Q82955', [[15]]]},
#  {'tokens': ['Tony',
#    'Calder',
#    '(',
#    '27',
#    'June',
#    '1943',
#    '–',
#    '2',
#    'January',
#    '2018',
#    ')',
#    'was',
#    'an',
#    'English',
#    'record',
#    'manager',
#    ',',
#    'impresario',
#    ',',
#    'talent',
#    '-',
#    'spotter',
#    ',',
#    'promoter',
#    'and',
#    'public',
#    'relations',
#    'agent',
#    '.'],
#   'h': ['tony calder', 'Q7822010', [[0, 1]]],
#   't': ['impresario', 'Q943995', [[17]]]},
#  {'tokens': ['German',
#    'pianist',
#    'and',
#    'composer',
#    'Theodor',
#    'Kullak',
#    '(',
#    '1818–1882',
#    ')',
#    'says',
#    'that',
#    'the',
#    'piece',
#    'is',
#    '"',
#    'full',
#    'of',
#    'Polish',
#    'elegance',
#    '.',
#    '"'],
#   'h': ['theodor kullak', 'Q706082', [[4, 5]]],
#   't': ['pianist', 'Q486748', [[1]]]},
#  {'tokens': ['Roger',
#    'Henrichsen',
#    '(',
#    '12',
#    'February',
#    '1876',
#    ',',
#    'Copenhagen',
#    '–',
#    '12',
#    'January',
#    '1926',
#    ',',
#    'Copenhagen',
#    ')',
#    'was',
#    'a',
#    'Danish',
#    'composer',
#    'and',
#    'pianist',
#    '.'],
#   'h': ['roger henrichsen', 'Q7358333', [[0, 1]]],
#   't': ['pianist', 'Q486748', [[20]]]},
#  {'tokens': ['Niji',
#    'Akanni',
#    'is',
#    'a',
#    'Nigerian',
#    ',',
#    'dramatist',
#    ',',
#    'Screenwriter',
#    ',',
#    'director',
#    ',',
#    'producer',
#    'and',
#    'filmmaker',
#    '.'],
#   'h': ['niji akanni', 'Q19897876', [[0, 1]]],
#   't': ['screenwriter', 'Q28389', [[8]]]},
#  {'tokens': ['Henri',
#    'Mialaret',
#    '(',
#    '2',
#    'August',
#    '1855',
#    'in',
#    'Charleville',
#    '-',
#    'Mézières',
#    ',',
#    'Ardennes',
#    ',',
#    'France',
#    '-',
#    '25',
#    'February',
#    '1919',
#    'in',
#    'Paris',
#    ')',
#    'was',
#    'a',
#    'French',
#    'sailor',
#    'who',
#    'competed',
#    'in',
#    'the',
#    '1900',
#    'Summer',
#    'Olympics',
#    '.'],
#   'h': ['henri mialaret', 'Q16842128', [[0, 1]]],
#   't': ['sailor', 'Q476246', [[24]]]},
#  {'tokens': ['Olivia',
#    'Gollan',
#    '(',
#    'born',
#    '27',
#    'August',
#    '1973',
#    ')',
#    'is',
#    'a',
#    'former',
#    'Australian',
#    'racing',
#    'cyclist',
#    '.'],
#   'h': ['olivia gollan', 'Q16864078', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[12, 13]]]},
#  {'tokens': ['František',
#    'Maxa',
#    '(',
#    'born',
#    '13',
#    'February',
#    '1923',
#    ')',
#    'is',
#    'a',
#    'Czech',
#    'former',
#    'sport',
#    'shooter',
#    'who',
#    'competed',
#    'in',
#    'the',
#    '1952',
#    'Summer',
#    'Olympics',
#    'and',
#    'in',
#    'the',
#    '1956',
#    'Summer',
#    'Olympics',
#    '.'],
#   'h': ['františek maxa', 'Q16089764', [[0, 1]]],
#   't': ['sport shooter', 'Q17486376', [[12, 13]]]},
#  {'tokens': ['Stuart',
#    'Charles',
#    '-',
#    'Fevrier',
#    'is',
#    'now',
#    'the',
#    'Pro',
#    'League',
#    "'s",
#    'longest',
#    '-',
#    'serving',
#    'current',
#    'manager',
#    'having',
#    'been',
#    'in',
#    'charge',
#    'of',
#    'the',
#    '"',
#    'Savonetta',
#    'Boys',
#    '"',
#    'of',
#    'W',
#    'Connection',
#    'since',
#    'June',
#    '2004',
#    '.'],
#   'h': ['stuart charles-fevrier', 'Q24954489', [[0, 1, 2, 3]]],
#   't': ['manager', 'Q628099', [[14]]]},
#  {'tokens': ['Melissa',
#    'Monet',
#    '(',
#    'born',
#    'July',
#    '16',
#    ',',
#    '1964',
#    ')',
#    'is',
#    'the',
#    'stage',
#    'name',
#    'of',
#    'an',
#    'American',
#    'pornographic',
#    'actress',
#    ',',
#    'writer',
#    'and',
#    'film',
#    'director',
#    '.'],
#   'h': ['melissa monet', 'Q11838404', [[0, 1]]],
#   't': ['pornographic actress', 'Q488111', [[16, 17]]]},
#  {'tokens': ['Liza',
#    'del',
#    'Sierra',
#    '(',
#    'also',
#    'spelled',
#    'Del',
#    'Sierra',
#    ',',
#    'born',
#    '30',
#    'August',
#    '1985',
#    ')',
#    'is',
#    'the',
#    'stage',
#    'name',
#    'of',
#    'a',
#    'French',
#    'pornographic',
#    'actress',
#    ',',
#    'film',
#    'director',
#    'and',
#    'producer',
#    '.'],
#   'h': ['liza del sierra', 'Q3257316', [[0, 1, 2]]],
#   't': ['pornographic actress', 'Q488111', [[21, 22]]]},
#  {'tokens': ['Demetrio',
#    'Volcic',
#    ',',
#    'also',
#    'known',
#    'in',
#    'Slovene',
#    'as',
#    'Mitja',
#    'Volčič',
#    '(',
#    'born',
#    '22',
#    'November',
#    '1931',
#    ')',
#    'is',
#    'an',
#    'Italian',
#    'journalist',
#    ',',
#    'author',
#    ',',
#    'and',
#    'politician',
#    'of',
#    'Slovenian',
#    'descent',
#    '.'],
#   'h': ['mitja volčič', 'Q1055212', [[8, 9]]],
#   't': ['politician', 'Q82955', [[24]]]},
#  {'tokens': ['Jörg',
#    'Dräger',
#    '(',
#    'born',
#    'January',
#    '1',
#    ',',
#    '1968',
#    ',',
#    'in',
#    'Darmstadt',
#    ')',
#    'is',
#    'a',
#    'German',
#    'physicist',
#    ',',
#    'politician',
#    'and',
#    'manager',
#    '.'],
#   'h': ['jörg dräger', 'Q1715292', [[0, 1]]],
#   't': ['politician', 'Q82955', [[17]]]},
#  {'tokens': ['Gert',
#    'Sabidussi',
#    '(',
#    'born',
#    '28',
#    'October',
#    '1929',
#    'in',
#    'Graz',
#    ')',
#    'is',
#    'an',
#    'Austrian',
#    'mathematician',
#    'specializing',
#    'in',
#    'combinatorics',
#    'and',
#    'graph',
#    'theory',
#    '.'],
#   'h': ['gert sabidussi', 'Q5553220', [[0, 1]]],
#   't': ['mathematician', 'Q170790', [[13]]]},
#  {'tokens': ['and',
#    'between',
#    'model',
#    'Katie',
#    'Downes',
#    'and',
#    'toilet',
#    'cleaner',
#    'Michelle',
#    'McManus',
#    '.'],
#   'h': ['katie downes', 'Q6377431', [[3, 4]]],
#   't': ['model', 'Q4610556', [[2]]]},
#  {'tokens': ['Winston',
#    'Chandarbhan',
#    'Dookeran',
#    '(',
#    'Hindi',
#    ':',
#    'विंस्टन',
#    'चंद्रभान',
#    'डूलेरन',
#    ';',
#    'born',
#    '24',
#    'June',
#    '1943',
#    ')',
#    'is',
#    'a',
#    'Trinidad',
#    'and',
#    'Tobago',
#    'politician',
#    'and',
#    'economist',
#    '.'],
#   'h': ['winston chandarbhan dookeran', 'Q8026079', [[0, 1, 2]]],
#   't': ['economist', 'Q188094', [[22]]]},
#  {'tokens': ['Michael',
#    'Peter',
#    'Drazin',
#    'is',
#    'American',
#    'mathematician',
#    ',',
#    'working',
#    'in',
#    'noncommutative',
#    'algebra',
#    '.'],
#   'h': ['michael peter drazin', 'Q6833293', [[0, 1, 2]]],
#   't': ['mathematician', 'Q170790', [[5]]]},
#  {'tokens': ['Joseph',
#    'Neri',
#    '(',
#    '26',
#    'July',
#    '1914',
#    '–',
#    '11',
#    'October',
#    '2005',
#    ')',
#    'was',
#    'a',
#    'French',
#    'racing',
#    'cyclist',
#    '.'],
#   'h': ['joseph neri', 'Q19519181', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[14, 15]]]},
#  {'tokens': ['Paul',
#    'Kline',
#    '(',
#    '1937',
#    '–',
#    '25',
#    'September',
#    '1999',
#    ')',
#    'was',
#    'a',
#    'psychologist',
#    'at',
#    'the',
#    'University',
#    'of',
#    'Exeter',
#    '.',
#    'Lea',
#    ',',
#    'Stephen',
#    '(',
#    '1999',
#    ')',
#    '.'],
#   'h': ['paul kline', 'Q7151813', [[0, 1]]],
#   't': ['psychologist', 'Q212980', [[11]]]},
#  {'tokens': ['The',
#    'plate',
#    'umpire',
#    ',',
#    'Cy',
#    'Rigler',
#    ',',
#    'claimed',
#    'he',
#    'should',
#    'have',
#    'called',
#    'the',
#    'previous',
#    'pitch',
#    'strike',
#    'three',
#    ',',
#    'that',
#    'would',
#    'have',
#    'ended',
#    'the',
#    'inning',
#    'with',
#    'a',
#    'perfection',
#    '.'],
#   'h': ['cy rigler', 'Q5197327', [[4, 5]]],
#   't': ['umpire', 'Q1856798', [[2]]]},
#  {'tokens': ['He',
#    'also',
#    'received',
#    '"',
#    'semicha',
#    '"',
#    'from',
#    'Rabbi',
#    'Eliezer',
#    'Yehuda',
#    'Finkel',
#    ',',
#    '"',
#    'rosh',
#    'yeshiva',
#    '"',
#    'of',
#    'the',
#    'Mir',
#    '.'],
#   'h': ['eliezer yehuda finkel', 'Q5360785', [[8, 9, 10]]],
#   't': ['rosh yeshiva', 'Q2308372', [[13, 14]]]},
#  {'tokens': ['Orlando',
#    'DiGirolamo',
#    '(',
#    'April',
#    '20',
#    ',',
#    '1924',
#    '–',
#    'January',
#    '26',
#    ',',
#    '1998',
#    ')',
#    'was',
#    'an',
#    'American',
#    'jazz',
#    'accordionist',
#    ',',
#    'pianist',
#    ',',
#    'composer',
#    ',',
#    'and',
#    'teacher',
#    '.'],
#   'h': ['orlando digirolamo', 'Q7103077', [[0, 1]]],
#   't': ['pianist', 'Q486748', [[19]]]},
#  {'tokens': ['Mike',
#    'Jaggerr',
#    '(',
#    'born',
#    'August',
#    '20',
#    ',',
#    '1989',
#    ')',
#    'is',
#    'a',
#    'rapper',
#    ',',
#    'producer',
#    ',',
#    'and',
#    'songwriter',
#    'and',
#    'former',
#    'band',
#    'member',
#    'of',
#    'the',
#    'hip',
#    '-',
#    'hop',
#    'group',
#    'Bassline',
#    '.'],
#   'h': ['mike jaggerr', 'Q6847379', [[0, 1]]],
#   't': ['songwriter', 'Q753110', [[16]]]},
#  {'tokens': ['In',
#    'the',
#    '2000s',
#    ',',
#    'Canadian',
#    'luthier',
#    'Linda',
#    'Manzer',
#    'created',
#    'the',
#    'Pikasso',
#    'guitar',
#    ',',
#    'a',
#    '42-string',
#    'guitar',
#    'with',
#    'three',
#    'necks',
#    '.'],
#   'h': ['linda manzer', 'Q302899', [[6, 7]]],
#   't': ['luthier', 'Q762707', [[5]]]},
#  {'tokens': ['Liliane',
#    'de',
#    'Kermadec',
#    '(',
#    'born',
#    '1928',
#    ')',
#    'is',
#    'a',
#    'French',
#    'film',
#    'director',
#    'and',
#    'screenwriter',
#    '.'],
#   'h': ['liliane de kermadec', 'Q607247', [[0, 1, 2]]],
#   't': ['screenwriter', 'Q28389', [[13]]]},
#  {'tokens': ['Philippe',
#    'Martinez',
#    'is',
#    'a',
#    'French',
#    'film',
#    'producer',
#    ',',
#    'director',
#    ',',
#    'screenwriter',
#    ',',
#    'actor',
#    ',',
#    'and',
#    'former',
#    'President',
#    'of',
#    'the',
#    'Odeon',
#    'Theater',
#    'in',
#    'Marseilles',
#    '.'],
#   'h': ['philippe martinez', 'Q3901505', [[0, 1]]],
#   't': ['director', 'Q2526255', [[8]]]},
#  {'tokens': ['Colleen',
#    'Shannon',
#    '(',
#    'born',
#    'April',
#    '14',
#    ',',
#    '1978',
#    ')',
#    'is',
#    'an',
#    'American',
#    'DJ',
#    'and',
#    'model',
#    'who',
#    'is',
#    '"',
#    'Playboy',
#    "'s",
#    '"',
#    'Playmate',
#    'of',
#    'the',
#    'Month',
#    'for',
#    'January',
#    '2004',
#    '.'],
#   'h': ['colleen shannon', 'Q16217612', [[0, 1]]],
#   't': ['playmate of the month', 'Q728711', [[21, 22, 23, 24]]]},
#  {'tokens': ['Originally',
#    'the',
#    'song',
#    'was',
#    'recorded',
#    'in',
#    'German',
#    'and',
#    'written',
#    'by',
#    'Drafi',
#    'Deutscher',
#    '.'],
#   'h': ['drafi deutscher', 'Q63152', [[10, 11]]],
#   't': ['written', 'Q753110', [[8]]]},
#  {'tokens': ['Fritz',
#    'Lang',
#    'was',
#    'an',
#    'Austrian',
#    'film',
#    'director',
#    ',',
#    'producer',
#    'and',
#    'screenwriter',
#    '.'],
#   'h': ['fritz lang', 'Q19504', [[0, 1]]],
#   't': ['film director', 'Q2526255', [[5, 6]]]},
#  {'tokens': ['Franny',
#    'Griffiths',
#    '(',
#    '1',
#    'July',
#    '1966',
#    ',',
#    'Liverpool',
#    ',',
#    'England',
#    ')',
#    'is',
#    'a',
#    'pianist',
#    'producer',
#    'and',
#    'remixer',
#    ',',
#    'who',
#    'is',
#    'best',
#    'known',
#    'for',
#    'being',
#    'a',
#    'member',
#    'of',
#    'the',
#    'band',
#    ',',
#    'Space',
#    '.'],
#   'h': ['franny griffiths', 'Q5492314', [[0, 1]]],
#   't': ['producer', 'Q183945', [[14]]]},
#  {'tokens': ['Johann',
#    'Dulnig',
#    '(',
#    '13',
#    'September',
#    '1878',
#    '–',
#    '6',
#    'June',
#    '1970',
#    ')',
#    'was',
#    'an',
#    'Austrian',
#    'sports',
#    'shooter',
#    '.'],
#   'h': ['johann dulnig', 'Q18639193', [[0, 1]]],
#   't': ['sports shooter', 'Q17486376', [[14, 15]]]},
#  {'tokens': ['Unni',
#    'Larsen',
#    '(',
#    'born',
#    '23',
#    'March',
#    '1959',
#    ')',
#    'is',
#    'a',
#    'Norwegian',
#    'former',
#    'racing',
#    'cyclist',
#    'and',
#    'dogsled',
#    'racer',
#    '.'],
#   'h': ['unni larsen', 'Q2496632', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[12, 13]]]},
#  {'tokens': ['The',
#    'landscape',
#    'gardener',
#    ',',
#    'Capability',
# ...
#    'Swiss',
#    'mathematician',
#    'and',
#    'astronomer',
#    '.'],
#   'h': ['daniel huber', 'Q18620256', [[0, 1]]],
#   't': ['mathematician', 'Q170790', [[16]]]},
#  {'tokens': ['Liisa',
#    'Ehrberg',
#    '(',
#    'born',
#    '17',
#    'December',
#    '1988',
#    ')',
#    'is',
#    'an',
#    'Estonian',
#    'racing',
#    'cyclist',
#    '.'],
#   'h': ['liisa ehrberg', 'Q18164750', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[11, 12]]]},
#  {'tokens': ['The',
#    'Black',
#    'Leather',
#    'Jacket',
#    'is',
#    'a',
#    'book',
#    'written',
#    'by',
#    'English',
#    'journalist',
#    'and',
#    'author',
#    'Mick',
#    'Farren',
#    'published',
#    'in',
#    '1985',
#    '.'],
#   'h': ['mick farren', 'Q465257', [[13, 14]]],
#   't': ['author', 'Q36180', [[12]]]},
#  {'tokens': ['Gregg',
#    'Heschong',
#    'is',
#    'an',
#    'American',
#    'cinematographer',
#    'and',
#    'television',
#    'director',
#    '.'],
#   'h': ['gregg heschong', 'Q5606545', [[0, 1]]],
#   't': ['television director', 'Q2059704', [[7, 8]]]},
#  {'tokens': ['Francis',
#    'Grignon',
#    '(',
#    'born',
#    '3',
#    'January',
#    '1944',
#    ')',
#    'is',
#    'a',
#    'French',
#    'politician',
#    'and',
#    'a',
#    'member',
#    'of',
#    'the',
#    'Senate',
#    'of',
#    'France',
#    '.'],
#   'h': ['francis grignon', 'Q3081473', [[0, 1]]],
#   't': ['politician', 'Q82955', [[11]]]},
#  {'tokens': ['Margarethe',
#    'Schreinemakers',
#    '(',
#    'born',
#    '27',
#    'July',
#    '1958',
#    ')',
#    'is',
#    'a',
#    'German',
#    'television',
#    'presenter',
#    ',',
#    'talk',
#    'show',
#    'host',
#    'and',
#    'journalist',
#    '.'],
#   'h': ['margarethe schreinemakers', 'Q97157', [[0, 1]]],
#   't': ['television presenter', 'Q947873', [[11, 12]]]},
#  {'tokens': ['Ken',
#    'Tamplin',
#    '(',
#    'born',
#    'December',
#    '11',
#    ',',
#    '1963',
#    ')',
#    'is',
#    'an',
#    'American',
#    'Christian',
#    'rock',
#    'performer',
#    'and',
#    'vocal',
#    'coach',
#    '.'],
#   'h': ['ken tamplin', 'Q1738666', [[0, 1]]],
#   't': ['vocal coach', 'Q2350126', [[16, 17]]]},
#  {'tokens': ['The',
#    'Bullets',
#    'broke',
#    'up',
#    'in',
#    '1990',
#    'and',
#    'Stevens',
#    'remained',
#    'on',
#    'Atlantic',
#    'as',
#    'a',
#    'solo',
#    'artist',
#    ',',
#    'working',
#    'with',
#    'record',
#    'producer',
#    'Keith',
#    'Stegall',
#    'for',
#    'a',
#    'solo',
#    'debut',
#    'album',
#    'which',
#    'was',
#    'never',
#    'released',
#    '.'],
#   'h': ['keith stegall', 'Q6385065', [[20, 21]]],
#   't': ['record producer', 'Q183945', [[18, 19]]]},
#  {'tokens': ['Recording',
#    'sessions',
#    'began',
#    'in',
#    '1995',
#    'with',
#    'various',
#    'record',
#    'producers',
#    ',',
#    'including',
#    'Nellee',
#    'Hooper',
#    ',',
#    'Flood',
#    ',',
#    'Howie',
#    'B',
#    ',',
#    'and',
#    'Osborne',
#    ',',
#    'who',
#    'were',
#    'introducing',
#    'the',
#    'band',
#    'to',
#    'various',
#    'electronica',
#    'influences',
#    '.'],
#   'h': ['howie b', 'Q974221', [[16, 17]]],
#   't': ['producers', 'Q183945', [[8]]]},
#  {'tokens': ['On',
#    '11',
#    'May',
#    '2010',
#    ',',
#    'Parker',
#    'was',
#    'revealed',
#    'to',
#    'be',
#    'among',
#    'manager',
#    'Fabio',
#    'Capello',
#    "'s",
#    '30-man',
#    'preliminary',
#    'squad',
#    'list',
#    'for',
#    'the',
#    '2010',
#    'FIFA',
#    'World',
#    'Cup',
#    '.'],
#   'h': ['fabio capello', 'Q183108', [[12, 13]]],
#   't': ['manager', 'Q628099', [[11]]]},
#  {'tokens': ['David',
#    'Urquhart',
#    '(',
#    '1',
#    'July',
#    '180516',
#    'May',
#    '1877',
#    ')',
#    'was',
#    'a',
#    'Scottish',
#    'diplomat',
#    ',',
#    'writer',
#    'and',
#    'politician',
#    ',',
#    'serving',
#    'as',
#    'a',
#    'Member',
#    'of',
#    'Parliament',
#    'from',
#    '1847',
#    'to',
#    '1852',
#    '.'],
#   'h': ['david urquhart', 'Q334374', [[0, 1]]],
#   't': ['diplomat', 'Q193391', [[12]]]},
#  {'tokens': ['Julius',
#    'Dessauer',
#    '(',
#    '1832–1883',
#    ')',
#    'was',
#    'a',
#    'Hungarian',
#    'rabbi',
#    'and',
#    'writer',
#    '.'],
#   'h': ['julius dessauer', 'Q6309746', [[0, 1]]],
#   't': ['rabbi', 'Q133485', [[8]]]},
#  {'tokens': ['Domenico',
#    'Guglielmini',
#    '(',
#    'Bologna',
#    ',',
#    '27',
#    'September',
#    '1655',
#    '-',
#    'Padoa',
#    ',',
#    '27',
#    'July',
#    '1710',
#    ')',
#    'was',
#    'an',
#    'Italian',
#    'mathematician',
#    ',',
#    'chemist',
#    'and',
#    'physician',
#    '.'],
#   'h': ['domenico guglielmini', 'Q910092', [[0, 1]]],
#   't': ['mathematician', 'Q170790', [[18]]]},
#  {'tokens': ['Daniel',
#    'Hunt',
#    'is',
#    'an',
#    'English',
#    'musician',
#    ',',
#    'songwriter',
#    'and',
#    'producer',
#    '.'],
#   'h': ['daniel hunt', 'Q5217554', [[0, 1]]],
#   't': ['songwriter', 'Q753110', [[7]]]},
#  {'tokens': ['Koldo',
#    'Serra',
#    'is',
#    'a',
#    'Spanish',
#    'director',
#    'and',
#    'screenwriter',
#    ',',
#    'born',
#    '1975',
#    'in',
#    'Bilbao',
#    ',',
#    'Spain',
#    '.'],
#   'h': ['koldo serra', 'Q3026790', [[0, 1]]],
#   't': ['screenwriter', 'Q28389', [[7]]]},
#  {'tokens': ['Eliza',
#    'Newton',
#    'Woolsey',
#    'Howland',
#    '(',
#    '1826',
#    '–',
#    '1917',
#    ')',
#    'was',
#    'an',
#    'American',
#    'author',
#    'and',
#    'the',
#    'wife',
#    'of',
#    'Union',
#    'Army',
#    'officer',
#    'Joseph',
#    'Howland',
#    '.'],
#   'h': ['joseph howland', 'Q6284098', [[20, 21]]],
#   't': ['officer', 'Q189290', [[19]]]},
#  {'tokens': ['Hanan',
#    'Tork',
#    '(',
#    ')',
#    '(',
#    'born',
#    'March',
#    '7',
#    ',',
#    '1975',
#    ')',
#    'is',
#    'an',
#    'Egyptian',
#    'former',
#    'actress',
#    'and',
#    'former',
#    'ballerina',
#    '.'],
#   'h': ['hanan tork', 'Q5646909', [[0, 1]]],
#   't': ['ballerina', 'Q805221', [[18]]]},
#  {'tokens': ['"',
#    'Pictures',
#    'of',
#    'Lily',
#    '"',
#    'is',
#    'a',
#    'single',
#    'by',
#    'the',
#    'British',
#    'rock',
#    'band',
#    'The',
#    'Who',
#    ',',
#    'written',
#    'by',
#    'guitarist',
#    'and',
#    'primary',
#    'songwriter',
#    'Pete',
#    'Townshend',
#    '.'],
#   'h': ['pete townshend', 'Q26933', [[22, 23]]],
#   't': ['guitarist', 'Q855091', [[18]]]},
#  {'tokens': ['Henry',
#    'Schultz',
#    '(',
#    'September',
#    '4',
#    ',',
#    '1893',
#    '–',
#    'November',
#    '26',
#    ',',
#    '1938',
#    ')',
#    'was',
#    'an',
#    'American',
#    'economist',
#    ',',
#    'statistician',
#    ',',
#    'and',
#    'one',
#    'of',
#    'the',
#    'founders',
#    'of',
#    'econometrics',
#    '.'],
#   'h': ['henry schultz', 'Q1971751', [[0, 1]]],
#   't': ['statistician', 'Q2732142', [[18]]]},
#  {'tokens': ['Joseph',
#    'Billington',
#    'was',
#    'an',
#    'English',
#    'footballer',
#    '.'],
#   'h': ['joseph billington', 'Q6281530', [[0, 1]]],
#   't': ['footballer', 'Q937857', [[5]]]},
#  {'tokens': ['Stefan',
#    'Kolev',
#    '(;',
#    'born',
#    '11',
#    'October',
#    '1966',
#    ')',
#    'is',
#    'a',
#    'Bulgarian',
#    'football',
#    'manager',
#    'and',
#    'former',
#    'footballer',
#    ',',
#    'who',
#    'played',
#    'as',
#    'a',
#    'defender',
#    '.'],
#   'h': ['stefan kolev', 'Q12295227', [[0, 1]]],
#   't': ['football manager', 'Q628099', [[11, 12]]]},
#  {'tokens': ['It',
#    'is',
#    'now',
#    'an',
#    'imprint',
#    'of',
#    'Hodder',
#    'Headline',
#    ',',
#    'and',
#    'is',
#    'known',
#    'for',
#    'its',
#    'military',
#    'history',
#    'books',
#    ',',
#    'including',
#    'works',
#    'by',
#    'historian',
#    'David',
#    'Nicolle',
#    '.'],
#   'h': ['david nicolle', 'Q1175909', [[22, 23]]],
#   't': ['historian', 'Q201788', [[21]]]},
#  {'tokens': ['He',
#    'kept',
#    'fuelling',
#    'the',
#    'war',
#    'through',
#    'other',
#    'bomb',
#    'attacks',
#    'and',
#    'killings',
#    '.',
#    'Dickie',
#    ',',
#    '"',
#    'Cosa',
#    'Nostra',
#    '"',
#    ',',
#    'p.',
#    '315',
#    '-',
#    '16',
#    'Another',
#    'pentito',
#    ',',
#    'Gaetano',
#    'Grado',
#    ',',
#    'confirmed',
#    'Buscetta',
#    '’s',
#    'testimony',
#    '.'],
#   'h': ['gaetano grado', 'Q18043965', [[26, 27]]],
#   't': ['pentito', 'Q2032656', [[24]]]},
#  {'tokens': ['Günter',
#    'Weitling',
#    '(',
#    'born',
#    '1935',
#    ')',
#    'is',
#    'a',
#    'Lutheran',
#    'theologian',
#    ',',
#    'historian',
#    ',',
#    'and',
#    'author',
#    '.'],
#   'h': ['günter weitling', 'Q107503', [[0, 1]]],
#   't': ['theologian', 'Q1234713', [[9]]]},
#  {'tokens': ['The',
#    '1959',
#    'film',
#    'was',
#    'directed',
#    'by',
#    'Italian',
#    'film',
#    'director',
#    ',',
#    'Marco',
#    'Ferreri',
#    '.'],
#   'h': ['marco ferreri', 'Q53018', [[10, 11]]],
#   't': ['film director', 'Q2526255', [[7, 8]]]},
#  {'tokens': ['McEntire',
#    'called',
#    'Tony',
#    'Brown',
#    ',',
#    'then',
#    'working',
#    'as',
#    'a',
#    'record',
#    'producer',
#    'for',
#    'both',
#    'her',
#    'and',
#    'Judd',
#    '.'],
#   'h': ['tony brown', 'Q7821969', [[2, 3]]],
#   't': ['record producer', 'Q183945', [[9, 10]]]},
#  {'tokens': ['He',
#    'and',
#    'comedian',
#    'Michael',
#    'Richards',
#    'were',
#    'involved',
#    'in',
#    'a',
#    'staged',
#    'on',
#    '-',
#    'air',
#    'fight',
#    'with',
#    'Andy',
#    'Kaufman',
#    ',',
#    'later',
#    're',
#    '-',
#    'created',
#    'in',
#    'the',
#    'Kaufman',
#    'biopic',
#    '"',
#    'Man',
#    'on',
#    'the',
#    'Moon',
#    '"',
#    '.'],
#   'h': ['michael richards', 'Q314945', [[3, 4]]],
#   't': ['comedian', 'Q18545066', [[2]]]},
#  {'tokens': ['Jacobs',
#    'directed',
#    'the',
#    '2015',
#    'documentary',
#    'short',
#    '"',
#    'The',
#    'Queen',
#    'of',
#    'Code',
#    '"',
#    'about',
#    'computer',
#    'scientist',
#    'and',
#    'United',
#    'States',
#    'Navy',
#    'rear',
#    'admiral',
#    'Grace',
#    'Hopper',
#    '.'],
#   'h': ['grace hopper', 'Q11641', [[21, 22]]],
#   't': ['computer scientist', 'Q82594', [[13, 14]]]},
#  {'tokens': ['He',
#    'was',
#    'the',
#    'father',
#    'of',
#    'typographer',
#    'Matthew',
#    'Carter',
#    '.'],
#   'h': ['matthew carter', 'Q383244', [[6, 7]]],
#   't': ['typographer', 'Q354034', [[5]]]},
#  {'tokens': ['In',
#    '1820',
#    'Edward',
#    'Eagar',
#    'brought',
#    'a',
#    '"',
#    'qui',
#    'tam',
#    '"',
#    'action',
#    'against',
#    'the',
#    'American',
#    'merchant',
#    'Prosper',
#    'de',
#    'Mestre',
#    '.'],
#   'h': ['prosper de mestre', 'Q7250882', [[15, 16, 17]]],
#   't': ['merchant', 'Q215536', [[14]]]},
#  {'tokens': ['Oliver',
#    'Madox',
#    'Hueffer',
#    '(',
#    '1877',
#    '–',
#    '22',
#    'June',
#    '1931',
#    ')',
#    ',',
#    'was',
#    'an',
#    'author',
#    ',',
#    'playwright',
#    ',',
#    'and',
#    'war',
#    'correspondent',
#    '.'],
#   'h': ['oliver madox hueffer', 'Q7087680', [[0, 1, 2]]],
#   't': ['war correspondent', 'Q164236', [[18, 19]]]},
#  {'tokens': ['Helena',
#    'Štáchová',
#    '(',
#    'November',
#    '18',
#    ',',
#    '1944',
#    '–',
#    'March',
#    '22',
#    ',',
#    '2017',
#    ')',
#    'was',
#    'a',
#    'Czech',
#    'puppeteer',
#    ',',
#    'voice',
#    'actress',
#    'and',
#    'playwright',
#    '.'],
#   'h': ['helena štáchová', 'Q12019448', [[0, 1]]],
#   't': ['voice actress', 'Q2405480', [[18, 19]]]},
#  {'tokens': ['Wild',
#    'Is',
#    'the',
#    'Wind',
#    'is',
#    'jazz',
#    'singer',
#    '-',
#    'songwriter',
#    'and',
#    'pianist',
#    'Nina',
#    'Simone',
#    "'s",
#    'sixth',
#    'album',
#    'for',
#    'Philips',
#    'Records',
#    '.'],
#   'h': ['nina simone', 'Q174957', [[11, 12]]],
#   't': ['pianist', 'Q486748', [[10]]]},
#  {'tokens': ['Antônio',
#    'Vicente',
#    'da',
#    'Fontoura',
#    '(',
#    'June',
#    '16',
#    ',',
#    '1807',
#    '–',
#    'October',
#    '20',
#    ',',
#    '1860',
#    ')',
#    'was',
#    'a',
#    'Brazilian',
#    'statesman',
#    '.'],
#   'h': ['antônio vicente da fontoura', 'Q4777674', [[0, 1, 2, 3]]],
#   't': ['statesman', 'Q82955', [[18]]]},
#  {'tokens': ['Robert',
#    'Mazlo',
#    'is',
#    'a',
#    'French',
#    'art',
#    'jeweller',
#    'and',
#    'goldsmith',
#    'of',
#    'Lebanese',
#    'origin',
#    'who',
#    'has',
#    'been',
#    'the',
#    'head',
#    'of',
#    'the',
#    'Paris',
#    '-',
#    'based',
#    'Mazlo',
#    'jewellery',
#    'house',
#    'since',
#    'the',
#    'late',
#    '1970s',
#    '.'],
#   'h': ['robert mazlo', 'Q7347449', [[0, 1]]],
#   't': ['goldsmith', 'Q211423', [[8]]]},
#  {'tokens': ['Jindřich',
#    'Trpišovský',
#    '(',
#    'born',
#    '27',
#    'February',
#    '1976',
#    ')',
#    'is',
#    'a',
#    'Czech',
#    'football',
#    'manager',
#    'who',
#    'is',
#    'currently',
#    'the',
#    'manager',
#    'of',
#    'Slavia',
#    'Prague',
#    '.'],
#   'h': ['jindřich trpišovský', 'Q20303124', [[0, 1]]],
#   't': ['manager', 'Q628099', [[12], [17]]]},
#  {'tokens': ['Pablo',
#    'Bardauil',
#    '(',
#    'born',
#    'December',
#    '23',
#    ',',
#    '1963',
#    ')',
#    'is',
#    'a',
#    'film',
#    'actor',
#    ',',
#    'director',
#    ',',
#    'and',
#    'screenplay',
#    'writer',
#    '.'],
#   'h': ['pablo bardauil', 'Q7121575', [[0, 1]]],
#   't': ['director', 'Q2526255', [[14]]]},
#  {'tokens': ['On',
#    '29',
#    'May',
#    '2017',
#    ',',
#    'Valverde',
#    'replaced',
#    'Luis',
#    'Enrique',
#    'as',
#    'the',
#    'new',
#    'Barcelona',
#    'manager',
#    '.'],
#   'h': ['luis enrique', 'Q222789', [[7, 8]]],
#   't': ['manager', 'Q628099', [[13]]]},
#  {'tokens': ['James',
#    'Dallas',
#    'Burrus',
#    '(',
#    '14',
#    'October',
#    '1846',
#    '–',
#    '5',
#    'December',
#    '1928',
#    ')',
#    'was',
#    'an',
#    'African',
#    '-',
#    'American',
#    'educator',
#    ',',
#    'druggist',
#    'and',
#    'philanthropist',
#    '.'],
#   'h': ['james dallas burrus', 'Q24203424', [[0, 1, 2]]],
#   't': ['druggist', 'Q105186', [[19]]]},
#  {'tokens': ['On',
#    '2',
#    'June',
#    '2012',
#    ',',
#    'Lambert',
#    'was',
#    'confirmed',
#    'as',
#    'the',
#    'new',
#    'manager',
#    'of',
#    'Aston',
#    'Villa',
#    'replacing',
#    'Alex',
#    'McLeish',
#    ',',
#    'who',
#    'was',
#    'sacked',
#    'two',
#    'weeks',
#    'earlier',
#    '.'],
#   'h': ['alex mcleish', 'Q316701', [[16, 17]]],
#   't': ['manager', 'Q628099', [[11]]]},
#  {'tokens': ['Andreas',
#    'Londos',
#    '(',
#    ',',
#    '1786–1846',
#    ')',
#    'was',
#    'a',
#    'Greek',
#    'military',
#    'leader',
#    'and',
#    'politician',
#    '.'],
#   'h': ['andreas londos', 'Q2362055', [[0, 1]]],
#   't': ['politician', 'Q82955', [[12]]]},
#  {'tokens': ['DJ',
#    'Muggs',
#    'vs.',
#    'Ill',
#    'Bill',
#    ':',
#    'Kill',
#    'Devil',
#    'Hills',
#    'is',
#    'a',
#    'collaboration',
#    'studio',
#    'album',
#    'by',
#    'the',
#    'American',
#    'rapper',
#    'Ill',
#    'Bill',
#    'and',
#    'producer',
#    'DJ',
#    'Muggs',
#    '.'],
#   'h': ['dj muggs', 'Q955323', [[0, 1], [22, 23]]],
#   't': ['producer', 'Q183945', [[21]]]},
#  {'tokens': ['Gino',
#    'Ferrin',
#    '(',
#    'born',
#    '15',
#    'March',
#    '1947',
#    'in',
#    'Berlin',
#    ')',
#    'is',
#    'a',
#    'retired',
#    'German',
#    'football',
#    'manager',
#    'and',
#    'former',
#    'player',
#    '.'],
#   'h': ['gino ferrin', 'Q1525094', [[0, 1]]],
#   't': ['manager', 'Q628099', [[15]]]},
#  {'tokens': ['Peter',
#    'Erler',
#    '(',
#    'born',
#    '10',
#    'April',
#    '1961',
#    'in',
#    'Weißenfels',
#    ')',
#    'is',
#    'a',
#    'German',
#    'historian',
#    '.'],
#   'h': ['peter erler', 'Q1562009', [[0, 1]]],
#   't': ['historian', 'Q201788', [[13]]]},
#  {'tokens': ['In',
#    '1971',
#    ',',
#    'he',
#    'accepted',
#    'Jean',
#    'Guillou',
#    '’s',
#    'invitation',
#    'to',
#    'become',
#    'co',
#    '-',
#    'titular',
#    'organist',
#    'at',
#    'Saint',
#    '-',
#    'Eustache',
#    'in',
#    'Paris',
#    '.'],
#   'h': ['jean guillou', 'Q1349794', [[5, 6]]],
#   't': ['organist', 'Q765778', [[14]]]},
#  {'tokens': ['Sergey',
#    'Pomoshnikov',
#    '(',
#    'born',
#    '17',
#    'July',
#    '1990',
#    ')',
#    'is',
#    'a',
#    'Russian',
#    'professional',
#    'racing',
#    'cyclist',
#    '.'],
#   'h': ['sergey pomoshnikov', 'Q1557789', [[0, 1]]],
#   't': ['racing cyclist', 'Q2309784', [[12, 13]]]},
#  {'tokens': ['Alan',
#    'Metzger',
#    'is',
#    'an',
#    'American',
#    'film',
#    'director',
#    ',',
#    'cinematographer',
#    'and',
#    'producer',
#    '.'],
#   'h': ['alan metzger', 'Q4707321', [[0, 1]]],
#   't': ['cinematographer', 'Q222344', [[8]]]},
#  {'tokens': ['Naomi',
#    'Wilkinson',
#    '(',
#    'born',
#    '30',
#    'June',
#    '1976',
#    ',',
#    'in',
#    'Bristol',
#    ',',
#    'England',
#    ')',
#    'is',
#    'an',
#    'English',
#    'television',
#    'presenter',
#    'and',
#    'actress',
#    '.'],
#   'h': ['naomi wilkinson', 'Q6964712', [[0, 1]]],
#   't': ['television presenter', 'Q947873', [[16, 17]]]}]

# %% [markdown]
# Действительно, по структуре эти сущности похожи. Сравним, например,
# 'George Chapman (?1559-?1634) was a successful playwright' (Р106)
# и
# 'Hubert Ney (12 October 1892 – 3 February 1984) was a German politician' (Р102)
# Вполне очевидно, что эти классы легко спутать.

# %% [markdown]
# ### Статья:
# Batista D. S., Martins B., Silva M. J. Semi-supervised bootstrapping of relationship extractors with distributional semantics
#
# ### Определения
#
# semantic drift - отличие семантики извлечённых отношений от семантики отношений, составляющих ядро (при бутстрэпинге).
#
# DIPRE (Dual Iterative Pattern Relation Expansion) - система извлечения отношений, предложенная С. Брином в 1998 г. Была создана для извлечения из текстов из Интернета отношений вида (автор, книга).
#
# ReVerb - система извлечения бинарных отношений (типа {arg1} is located in {arg2}, {arg1} built {arg2} и т.д.), разработанная в Университете Вашингтона в 2011 году. Данные доступны здесь: http://reverb.cs.washington.edu/
#
# Freebase - графовая база знаний, разработанная компанией Metaweb в 2008 г. Имеет версию FreebaseEasy, из которой можно легко извлечь уникальные имена сущностей и бинарные отношения между ними.
